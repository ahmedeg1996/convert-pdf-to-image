# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

from imutils.perspective import four_point_transform
from skimage import exposure, img_as_ubyte
from pdf2image import convert_from_path
from ModelUnetPlus import PrepareImage
from ModelUnetPlus import CreateModel
from itertools import combinations
from os.path import join as pjoin
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import numpy as np
import collections
import imutils
import time
import cv2
import sys

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (1.23.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (8.1.3)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (1.23.5)
# Requirement already satisfied: packaging<24,>=14.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (23.0)
# Requirement already satisfied: pandas<3,>=0.25 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow<10,>=6.2.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: pympler<2,>=0.9 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: python-dateutil<3,>=2 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.4 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (2.28.2)
# Requirement already satisfied: rich<14,>=10.11.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (13.4.1)
# Requirement already satisfied: tenacity<9,>=8.0.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (4.4.0)
# Requirement already satisfied: tzlocal<5,>=1.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (4.3)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (3.1.31)
# Requirement already satisfied: pydeck<1,>=0.1.dev5 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (6.2)
# Requirement already satisfied: watchdog in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from streamlit) (3.0.0)
# Requirement already satisfied: jinja2 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from gitpython!=3.1.19,<4,>=3->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.13.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from pandas<3,>=0.25->streamlit) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from python-dateutil<3,>=2->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from requests<3,>=2.4->streamlit) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from requests<3,>=2.4->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from requests<3,>=2.4->streamlit) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from requests<3,>=2.4->streamlit) (2022.12.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from rich<14,>=10.11.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from rich<14,>=10.11.0->streamlit) (2.14.0)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from tzlocal<5,>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from tzlocal<5,>=1.1->streamlit) (2023.2)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.11.0->streamlit) (0.1.2)

# %%
# !pip install -U openmim
# !mim install mmcv-lite
# Out:
# Requirement already satisfied: openmim in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (0.3.7)
# Requirement already satisfied: Click in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from openmim) (8.1.3)
# Requirement already satisfied: colorama in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from openmim) (0.1.11)
# Requirement already satisfied: pandas in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from openmim) (1.5.3)
# Requirement already satisfied: pip>=19.3 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from openmim) (23.1.2)
# Requirement already satisfied: requests in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from openmim) (13.4.1)
# Requirement already satisfied: tabulate in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: markdown in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from model-index->openmim) (3.4.1)
# Requirement already satisfied: ordered-set in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from pandas->openmim) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from pandas->openmim) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from requests->openmim) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from requests->openmim) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from requests->openmim) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from requests->openmim) (2022.12.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from rich->openmim) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from rich->openmim) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from python-dateutil>=2.8.1->pandas->openmim) (1.16.0)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cpu/torch2.0.0/index.html
# Requirement already satisfied: mmcv-lite in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (2.0.0)
# Requirement already satisfied: addict in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmcv-lite) (2.4.0)
# Requirement already satisfied: mmengine>=0.2.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmcv-lite) (0.7.4)
# Requirement already satisfied: numpy in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmcv-lite) (1.23.5)
# Requirement already satisfied: packaging in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmcv-lite) (23.0)
# Requirement already satisfied: Pillow in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmcv-lite) (9.4.0)
# Requirement already satisfied: pyyaml in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmcv-lite) (6.0)
# Requirement already satisfied: yapf in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmcv-lite) (0.33.0)
# Requirement already satisfied: regex in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmcv-lite) (2023.3.22)
# Requirement already satisfied: matplotlib in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmengine>=0.2.0->mmcv-lite) (3.7.0)
# Requirement already satisfied: rich in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmengine>=0.2.0->mmcv-lite) (13.4.1)
# Requirement already satisfied: termcolor in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmengine>=0.2.0->mmcv-lite) (2.2.0)
# Requirement already satisfied: opencv-python>=3 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from mmengine>=0.2.0->mmcv-lite) (4.7.0.68)
# Requirement already satisfied: tomli>=2.0.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from yapf->mmcv-lite) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv-lite) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv-lite) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv-lite) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv-lite) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv-lite) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv-lite) (2.8.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from rich->mmengine>=0.2.0->mmcv-lite) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from rich->mmengine>=0.2.0->mmcv-lite) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine>=0.2.0->mmcv-lite) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\v23asayed2\anaconda3\envs\ocr\lib\site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv-lite) (1.16.0)

# %%
def decode_map(label_mask):
    label_colors = get_card_colormap()
    r = label_mask.copy()
    g = label_mask.copy()
    b = label_mask.copy()
    for ll in range(0, 2):
        r[label_mask == ll] = label_colors[ll, 0]
        g[label_mask == ll] = label_colors[ll, 1]
        b[label_mask == ll] = label_colors[ll, 2]
    rgb = np.zeros((label_mask.shape[0], label_mask.shape[1], 3))
    rgb[:, :, 0] = r
    rgb[:, :, 1] = g
    rgb[:, :, 2] = b

    return rgb.astype(np.uint8)

# %%
def get_card_colormap():
    return np.asarray([[0, 0, 0], [255, 255, 255]])

# %%
def get_cnt(edged, img, ratio):
    kernel = np.ones((3, 3), np.uint8)
    edged = cv2.dilate(edged, kernel, iterations=1)
    mask = np.zeros((edged.shape[0], edged.shape[1]), np.uint8)
    mask[10:edged.shape[0] - 10, 10:edged.shape[1] - 10] = 1
    edged = edged * mask

    cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    # cnts = cnts[0] if imutils.is_cv2() else cnts[1]
    cnts = cnts[0] if imutils.is_cv2(or_better=True) else cnts[1]
    cnts = sorted(cnts, key=lambda c: cv2.arcLength(c, True), reverse=True)
    edgelines = np.zeros(edged.shape, np.uint8)
    cNum = 4

    for i in range(min(cNum, len(cnts))):
        TH = 1 / 20.0
        if cv2.contourArea(cnts[i]) < TH * img.shape[0] * img.shape[1]:
            cv2.drawContours(edgelines, [cnts[i]], 0, (255, 255, 255), -1)
        else:
            cv2.drawContours(edgelines, [cnts[i]], 0, (1, 1, 1), -1)
            edgelines = edgelines * edged
            break
        cv2.drawContours(edgelines, [cnts[i]], 0, (255, 255, 255), -1)

    if debug:
        cv2.imwrite(pjoin(debug_dir, name + "_edgelines.png"), edgelines)

    lines = cv2.HoughLines(edgelines, 1, np.pi / 180, 200)

    if lines is None or len(lines) < 4:
        if debug:
            print("Detection Error: Could not find enough lines (must more than 4) from the detected edge.")
        raise Exception("Lines not found.")

    if debug:
        lines_draw = np.zeros((len(lines), 4), dtype=int)
        img_draw = img.copy()
        for i in range(0, len(lines)):
            rho, theta = lines[i][0][0], lines[i][0][1]
            a = np.cos(theta)
            b = np.sin(theta)
            x0 = a * rho
            y0 = b * rho
            lines_draw[i][0] = int(x0 + 1000 * (-b))
            lines_draw[i][1] = int(y0 + 1000 * (a))
            lines_draw[i][2] = int(x0 - 1000 * (-b))
            lines_draw[i][3] = int(y0 - 1000 * (a))
            cv2.line(img_draw, (lines_draw[i][0], lines_draw[i][1]), (lines_draw[i][2], lines_draw[i][3]), (0, 255, 0),
                     1)
        cv2.imwrite(pjoin(debug_dir, name + '_hough1.png'), img_draw)

    strong_lines = np.zeros([4, 1, 2])
    n2 = 0

    for n1 in range(0, len(lines)):
        if n2 == 4:
            break
        for rho, theta in lines[n1]:
            if n1 == 0:
                strong_lines[n2] = lines[n1]
                n2 = n2 + 1
            else:
                c1 = np.isclose(abs(rho), abs(strong_lines[0:n2, 0, 0]), atol=80)
                c2 = np.isclose(np.pi - theta, strong_lines[0:n2, 0, 1], atol=np.pi / 36)
                c = np.all([c1, c2], axis=0)
                if any(c):
                    continue
                closeness_rho = np.isclose(rho, strong_lines[0:n2, 0, 0], atol=40)
                closeness_theta = np.isclose(theta, strong_lines[0:n2, 0, 1], atol=np.pi / 36)
                closeness = np.all([closeness_rho, closeness_theta], axis=0)
                if not any(closeness) and n2 < 4 and theta != 0:
                    strong_lines[n2] = lines[n1]
                    n2 = n2 + 1

    # draw strong lines
    lines1 = np.zeros((len(strong_lines), 4), dtype=int)
    for i in range(0, len(strong_lines)):
        rho, theta = strong_lines[i][0][0], strong_lines[i][0][1]
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a * rho
        y0 = b * rho
        lines1[i][0] = int(x0 + 1000 * (-b))
        lines1[i][1] = int(y0 + 1000 * (a))
        lines1[i][2] = int(x0 - 1000 * (-b))
        lines1[i][3] = int(y0 - 1000 * (a))

        if debug:
            cv2.line(img, (lines1[i][0], lines1[i][1]), (lines1[i][2], lines1[i][3]), (0, 255, 0), 3)

    approx = np.zeros((len(strong_lines), 1, 2), dtype=int)
    index = 0
    combs = list((combinations(lines1, 2)))
    for twoLines in combs:
        x1, y1, x2, y2 = twoLines[0]
        x3, y3, x4, y4 = twoLines[1]
        [x, y] = cross_point([x1, y1, x2, y2], [x3, y3, x4, y4])
        if 0 < x < img.shape[1] and 0 < y < img.shape[0] and index < 4:
            cv2.circle(img, (int(x), int(y)), 5, (0, 0, 255), 3)
            approx[index] = (int(x), int(y))
            index = index + 1

    if debug:
        cv2.imwrite(pjoin(debug_dir, name + '_hough2.png'), img)

    if checked_valid_transform(approx):
        return approx * ratio

# %%
def cross_point(line1, line2):
    x = 0
    y = 0
    x1 = line1[0]
    y1 = line1[1]
    x2 = line1[2]
    y2 = line1[3]
    x3 = line2[0]
    y3 = line2[1]
    x4 = line2[2]
    y4 = line2[3]
    if (x2 - x1) == 0:
        k1 = None
    else:
        k1 = (y2 - y1) * 1.0 / (x2 - x1)
        b1 = y1 * 1.0 - x1 * k1 * 1.0
    if (x4 - x3) == 0:
        k2 = None
        b2 = 0
    else:
        k2 = (y4 - y3) * 1.0 / (x4 - x3)
        b2 = y3 * 1.0 - x3 * k2 * 1.0
    if k1 is None:
        if not k2 is None:
            x = x1
            y = k2 * x1 + b2
    elif k2 is None:
        x = x3
        y = k1 * x3 + b1
    elif not k2 == k1:
        x = (b2 - b1) * 1.0 / (k1 - k2)
        y = k1 * x * 1.0 + b1 * 1.0

    return [x, y]

# %%
def checked_valid_transform(approx):
    hull = cv2.convexHull(approx)
    TH_ANGLE = 45
    if len(hull) == 4:
        for i in range(4):
            p1 = hull[(i - 1) % 4]
            p2 = hull[i]
            p3 = hull[(i + 1) % 4]
            angel = get_angle(p1, p2, p3)
            if 90 - TH_ANGLE < angel < 90 + TH_ANGLE:
                continue
            else:
                if debug:
                    print("Detection Error: The detected corners could not form a valid quadrilateral for transformation.")
                raise Exception("Corner points invalid.")from None
    else:
        if debug:
            print("Detection Error: Could not find four corners from the detected edge.")
        raise Exception("Corner points less than 4.")from None

    return True

# %%
def get_angle(sta_point, mid_point, end_point):
    ma_x = sta_point[0][0] - mid_point[0][0]
    ma_y = sta_point[0][1] - mid_point[0][1]
    mb_x = end_point[0][0] - mid_point[0][0]
    mb_y = end_point[0][1] - mid_point[0][1]
    ab_x = sta_point[0][0] - end_point[0][0]
    ab_y = sta_point[0][1] - end_point[0][1]
    ab_val2 = ab_x * ab_x + ab_y * ab_y
    ma_val2 = ma_x * ma_x + ma_y * ma_y
    mb_val2 = mb_x * mb_x + mb_y * mb_y
    cos_M = (ma_val2 + mb_val2 - ab_val2) / (2 * np.sqrt(ma_val2) * np.sqrt(mb_val2))
    angleAMB = np.arccos(cos_M) / np.pi * 180
    return angleAMB

# %%
def finetune(img, ratio):
    offset = int(2 * ratio)
    img = img[offset + 15:img.shape[0] - offset,
          int(offset * 2):img.shape[1] - int(offset * 2), :]
    if img.shape[0] < img.shape[1]:
        img = cv2.resize(img, (img.shape[1], int(img.shape[1] / 856 * 540)))
        r = int(img.shape[1] / 856 * 31.8)
    else:
        img = cv2.resize(img, (img.shape[1], int(img.shape[1] / 540 * 856)))
        r = int(img.shape[1] / 540 * 31.8)
    img = set_corner(img, r)
    if img.shape[0] > img.shape[1]:
        img = cv2.transpose(img)
        img = cv2.flip(img, 0)
    return img

# %%
def set_corner(img, r):
    b_channel, g_channel, r_channel = cv2.split(img)
    alpha_channel = np.ones(b_channel.shape, dtype=b_channel.dtype) * 255
    row = img.shape[0]
    col = img.shape[1]

    for i in range(0, r):
        for j in range(0, r):
            if (r - i) * (r - i) + (r - j) * (r - j) > r * r:
                alpha_channel[i][j] = 0

    for i in range(0, r):
        for j in range(col - r, col):
            if (r - i) * (r - i) + (r - col + j + 1) * (r - col + j + 1) > r * r:
                alpha_channel[i][j] = 0

    for i in range(row - r, row):
        for j in range(0, r):
            if (r - row + i + 1) * (r - row + i + 1) + (r - j) * (r - j) > r * r:
                alpha_channel[i][j] = 0

    for i in range(row - r, row):
        for j in range(col - r, col):
            if (r - row + i + 1) * (r - row + i + 1) + (r - col + j + 1) * (r - col + j + 1) > r * r:
                alpha_channel[i][j] = 0

    img_bgra = cv2.merge((b_channel, g_channel, r_channel, alpha_channel))

    return img_bgra

# %%
def detect_edge(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX)

    mean_gray = cv2.mean(gray)
    TH_LIGHT = 150
    if mean_gray[0] > TH_LIGHT:
        gray = exposure.adjust_gamma(gray, gamma=6)
        gray = exposure.equalize_adapthist(gray, kernel_size=None, clip_limit=0.02)
        gray = img_as_ubyte(gray)

    kernel = np.ones((15, 15), np.uint8)
    closing = cv2.morphologyEx(gray, cv2.MORPH_CLOSE, kernel)
    blurred = cv2.medianBlur(closing, 5)
    blurred = cv2.bilateralFilter(blurred, d=0, sigmaColor=15, sigmaSpace=10)

    edged = cv2.Canny(blurred, 75, 200)

    if debug:
        cv2.imwrite(pjoin(debug_dir, name + "_Cannyedge.png"), edged)

    return edged

# %%
def AprroxmateContour(thresh):
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)
    for eps in np.linspace(0.001, 0.05, 10):
        peri = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, eps * peri, True)
        if len(approx) ==4:
            break
    if len(approx) !=4 :
        raise Exception("Lines not found.")
    return approx

# %%
Model =CreateModel()
Model.load_weights("best_model.hdf5")

# %%
import os
from pdf2image import convert_from_path
import multiprocessing as mp

# Set the folder path where the PDF files are located
folder_path = r"C:\Users\v23ASayed2\Desktop\Vodafone\National_IDs_splitting\23-07-09"

def convert_pdf_to_jpeg(filename):
    try:
        # Convert the PDF file to a list of image pages using pdf2image
        pages = convert_from_path(os.path.join(folder_path, filename), poppler_path=r'C:\Users\v23ASayed2\Desktop\Vodafone\National_IDs_splitting\poppler-0.68.0_x86\poppler-0.68.0\bin')
        
        # Your image processing code...
        # Save each page of the PDF as a separate image file
        for i, image in enumerate(pages):
            image_size = image.size
            image_input = PrepareImage(image)
            predicted = np.where(Model.predict(image_input) > 0.9, 255, 0)
            mask_predicted = np.array(np.squeeze(predicted[0]), dtype='uint8')
            mask_predicted = cv2.resize(mask_predicted, (image_size[1], image_size[0]), interpolation=cv2.INTER_LINEAR)
            elements_count = collections.Counter(predicted[0].reshape(1, 256*256)[0])
            print(elements_count[255])
            if elements_count[255] > 350:
                image.save(os.path.join(r'C:\Users\v23ASayed2\Desktop\Vodafone\National_IDs_splitting\IDs_2', f'{filename[:-4]}_{i+1}.jpg'), 'JPEG')
            else:
                image.save(os.path.join(r'C:\Users\v23ASayed2\Desktop\Vodafone\National_IDs_splitting\Contracts_2', f'{filename[:-4]}_{i+1}.jpg'), 'JPEG')

    except Exception as e:
        print(f"Error processing PDF file: {filename}")
        print(f"Error message: {str(e)}")
        return

pdf_files = [filename for filename in os.listdir(folder_path) if filename.endswith(".pdf")]

# Convert each PDF file in the list to a list of image pages using pdf2image
for filename in pdf_files:
    convert_pdf_to_jpeg(filename)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 3121
# 1/1 [==============================] - 1s 748ms/step
# 0

# %%
print(len(os.listdir(".\imagesPdf")))
# Out:
# 1750

# %%
print(len(os.listdir(".\Contract")))
# Out:
# 729

# %%
import os
from pdf2image import convert_from_path
import multiprocessing as mp

# Set the folder path where the PDF files are located
folder_path = r"C:\Users\v23ASayed2\Desktop\Vodafone\National_IDs_splitting\23-07-09"

def convert_pdf_to_jpeg(filename):
    try:
        # Convert the PDF file to a list of image pages using pdf2image
        pages = convert_from_path(os.path.join(folder_path, filename), poppler_path=r'C:\Users\v23ASayed2\Desktop\Vodafone\National_IDs_splitting\poppler-0.68.0_x86\poppler-0.68.0\bin')
        
        # Your image processing code...
        # Save each page of the PDF as a separate image file
        for i, image in enumerate(pages):

            image.save(os.path.join(r'C:\Users\v23ASayed2\Desktop\Vodafone\National_IDs_splitting\test', f'{filename[:-4]}_{i+1}.jpg'), 'JPEG')


    except Exception as e:
        print(f"Error processing PDF file: {filename}")
        print(f"Error message: {str(e)}")
        return

pdf_files = [filename for filename in os.listdir(folder_path) if filename.endswith(".pdf")]

# Convert each PDF file in the list to a list of image pages using pdf2image
for filename in pdf_files:
    convert_pdf_to_jpeg(filename)
# Out:
# Error processing PDF file: 202211_C_2021011_1037_01090743579.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1046_01016246328.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_104_01093089496.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_1099_01090692685.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1169_01030176623.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1205_01091576431.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_1224_01094227410.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1370_01026441481.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1372_01026194765.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1375_01063091437.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (400005): Command token too long
# Syntax Error (400133): Command token too long
# Syntax Error (400261): Command token too long
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1419_01026180782.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Unterminated string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1440_01026193246.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1451_01091137013.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_153_01069190284.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1616_01098295434.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1650_01050748517.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_1654_01094247169.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1698_01032047299.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_1701_01098078631.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (360324): Illegal character ')'
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1832_01098027078.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_1920_01094058626.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_1970_01026435296.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_2014_01096490847.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_2092_01099278625.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_2219_01094279958.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_2348_01032493476.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_239_01020795418.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_2421_01094227410.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_253_01014619334.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_2647_01026156938.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_2683_01064018729.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_2800_01019452966.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_2904_01032191079.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_2906_01016368749.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_3130_01064281791.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_3137_01093025923.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_3197_01097412459.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_3229_01094251274.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (634506): Illegal character ')'
# Syntax Error (634507): Illegal character ')'
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_3293_01032548028.pdf
# Error message: Unable to get page count.
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_3323_01021771368.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_3416_01021971381.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_3545_01025939143.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_3563_01068235084.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_3600_01002645270.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3601_01032456365.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3605_01067335238.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3611_01069350391.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3614_01063452865.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_361_01032493476.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3620_01096456807.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3622_01026012937.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3623_01094250361.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (567756): Illegal character ')'
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_3626_01097039025.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_362_01019243296.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3634_01095377241.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3638_01064792134.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3640_01068903297.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3641_01091059842.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3643_01025664617.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3647_01028572416.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3650_01001587836.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3658_01020687644.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3659_01097645208.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3663_01032258459.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3664_01063318692.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3666_01025674520.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3668_01017413016.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3669_01063479615.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3670_01063926140.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3672_01097830253.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3673_01016851903.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_3674_01090287015.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3680_01021490627.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3682_01026433504.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3683_01016764465.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3684_01025168954.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3685_01064670926.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3693_01098264230.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3697_01017315236.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3701_01090714752.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_370_01026432756.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3711_01026435465.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3712_01028949985.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3717_01025903754.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_371_01032690752.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3728_01064359480.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3729_01063196715.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_372_01094846823.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3731_01032480629.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3732_01025983709.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3733_01024684995.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_3734_01016421897.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3736_01069973871.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3743_01025647987.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3744_01025647784.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3745_01094247718.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_3748_01019753450.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3750_01026971954.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3755_01024066831.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3757_01094507947.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3762_01016927835.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3764_01064827553.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3766_01019235791.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3768_01014840426.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_376_01015647453.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3774_01099435845.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_377_01012495236.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3782_01016379286.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_3788_01096193202.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3789_01064587486.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3791_01030357905.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3798_01062607405.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_379_01065303279.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3805_01096420151.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3812_01001187569.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3814_01097506410.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3815_01032086732.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_383_01098695723.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_384_01064780349.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_393_01017984361.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_398_01060459368.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_39_01025950463.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_3_01030532876.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_404_01063318572.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_421_01019584302.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_424_01097355286.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_428_01063064893.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_431_01001887967.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_433_01094243586.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (713528): Warning: name token is longer than what the specification says it can be
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_439_01003879646.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_442_01069853432.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_445_01021190362.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_446_01095285180.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_450_01017527696.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_451_01095393706.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_458_01020554142.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_459_01022134756.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_462_01094532916.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_468_01065127293.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_470_01093077195.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_471_01029648110.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_476_01098853285.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_47_01066897662.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (1244): Illegal character ')'
# Syntax Error (1245): Illegal character ')'
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_485_01018238598.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_488_01017985748.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_495_01033043625.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_499_01021260634.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_49_01068234190.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_4_01019250218.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_501_01096102634.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_504_01061920346.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_505_01032519582.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_507_01097798647.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_509_01060857247.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_50_01018994021.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_513_01064728298.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_515_01014327097.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_520_01064720463.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_524_01094791865.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_52_01015047952.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_530_01021184732.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_531_01028649657.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_532_01094248142.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_534_01025639473.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_535_01014796239.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_536_01016439724.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_537_01025972078.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_53_01023911546.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_541_01013758214.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_545_01032253857.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_547_01032392309.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_548_01091486131.pdf
# Error message: [Errno 28] No space left on device
# Error processing PDF file: 202211_C_2021011_562_01063071468.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_574_01027423749.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_588_01026184053.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (609362): Illegal character '{'
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_649_01026199859.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_657_01025290642.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_776_01032456361.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_80_01032258492.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_818_01025706812.pdf
# Error message: Unable to get page count.
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_829_01098247852.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_836_01023498310.pdf
# Error message: Unable to get page count.
#
# Error processing PDF file: 202211_C_2021011_882_01026153791.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing PDF file: 202211_C_2021011_997_01098210436.pdf
# Error message: Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (95114): Illegal character ')'
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
