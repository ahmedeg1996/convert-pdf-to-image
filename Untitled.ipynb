# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

from imutils.perspective import four_point_transform
from skimage import exposure, img_as_ubyte
from pdf2image import convert_from_path
from ModelUnetPlus import PrepareImage
from ModelUnetPlus import CreateModel
from itertools import combinations
from os.path import join as pjoin
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import numpy as np
import collections
import imutils
import time
import cv2
import sys
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.23.1-py2.py3-none-any.whl (8.9 MB)
#      ---------------------------------------- 8.9/8.9 MB 215.5 kB/s eta 0:00:00
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: toml<2 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Collecting pydeck<1,>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ---------------------------------------- 4.8/4.8 MB 443.3 kB/s eta 0:00:00
# Requirement already satisfied: click<9,>=7.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (8.1.3)
# Collecting pympler<2,>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ------------------------------------ 164.8/164.8 kB 412.2 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3,>=2 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Collecting altair<6,>=4.0
#   Downloading altair-5.0.1-py3-none-any.whl (471 kB)
#      ------------------------------------ 471.5/471.5 kB 223.6 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (4.3.0)
# Collecting rich<14,>=10.11.0
#   Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#      ------------------------------------ 239.4/239.4 kB 287.5 kB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.4 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: pillow<10,>=6.2.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: packaging<24,>=14.1 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (4.23.2)
# Requirement already satisfied: tenacity<9,>=8.0.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (8.0.1)
# Collecting validators<1,>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tzlocal<5,>=1.1
#   Downloading tzlocal-4.3-py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas<3,>=0.25 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (1.4.4)
# Requirement already satisfied: numpy<2,>=1 in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (1.21.5)
# Requirement already satisfied: watchdog in c:\users\v23aesseily\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Collecting gitpython!=3.1.19,<4,>=3
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ------------------------------------ 184.3/184.3 kB 337.4 kB/s eta 0:00:00
# Collecting pyarrow>=4.0
#   Downloading pyarrow-12.0.1-cp39-cp39-win_amd64.whl (21.5 MB)
#      -------------------------------------- 21.5/21.5 MB 305.6 kB/s eta 0:00:00
# Requirement already satisfied: toolz in c:\users\v23aesseily\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.11.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.16.0)
# Requirement already satisfied: jinja2 in c:\users\v23aesseily\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: colorama in c:\users\v23aesseily\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.5)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      -------------------------------------- 62.7/62.7 kB 481.6 kB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\v23aesseily\anaconda3\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\v23aesseily\anaconda3\lib\site-packages (from packaging<24,>=14.1->streamlit) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\v23aesseily\anaconda3\lib\site-packages (from pandas<3,>=0.25->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\v23aesseily\anaconda3\lib\site-packages (from python-dateutil<3,>=2->streamlit) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\v23aesseily\anaconda3\lib\site-packages (from requests<3,>=2.4->streamlit) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\v23aesseily\anaconda3\lib\site-packages (from requests<3,>=2.4->streamlit) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\v23aesseily\anaconda3\lib\site-packages (from requests<3,>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\v23aesseily\anaconda3\lib\site-packages (from requests<3,>=2.4->streamlit) (1.26.11)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading Pygments-2.15.1-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 238.4 kB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      -------------------------------------- 87.5/87.5 kB 206.1 kB/s eta 0:00:00
# Collecting tzdata
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ------------------------------------ 341.8/341.8 kB 249.7 kB/s eta 0:00:00
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py): started
#   Building wheel for validators (setup.py): finished with status 'done'
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=763fa5c11169d01b8fde96a16df516dc4aac0b592afcdf4597aa7e3895ae709e
#   Stored in directory: c:\users\v23aesseily\appdata\local\pip\cache\wheels\2d\f0\a8\1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: validators, tzdata, smmap, pympler, pygments, pyarrow, mdurl, pytz-deprecation-shim, pydeck, markdown-it-py, gitdb, tzlocal, rich, gitpython, altair, streamlit
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
# Successfully installed altair-5.0.1 gitdb-4.0.10 gitpython-3.1.31 markdown-it-py-3.0.0 mdurl-0.1.2 pyarrow-12.0.1 pydeck-0.8.1b0 pygments-2.15.1 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-13.4.2 smmap-5.0.0 streamlit-1.23.1 tzdata-2023.3 tzlocal-4.3 validators-0.20.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)

# %%
# !pip install -U openmim
# !mim install mmcv-lite
# Out:
# Collecting openmim
#   Downloading openmim-0.3.7-py2.py3-none-any.whl (51 kB)
#      -------------------------------------- 51.3/51.3 kB 219.7 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\v23aesseily\anaconda3\lib\site-packages (from openmim) (2.28.1)
# Collecting model-index
#   Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Requirement already satisfied: rich in c:\users\v23aesseily\anaconda3\lib\site-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in c:\users\v23aesseily\anaconda3\lib\site-packages (from openmim) (0.8.10)
# Requirement already satisfied: Click in c:\users\v23aesseily\anaconda3\lib\site-packages (from openmim) (8.1.3)
# Requirement already satisfied: pip>=19.3 in c:\users\v23aesseily\anaconda3\lib\site-packages (from openmim) (22.2.2)
# Requirement already satisfied: colorama in c:\users\v23aesseily\anaconda3\lib\site-packages (from openmim) (0.4.5)
# Requirement already satisfied: pandas in c:\users\v23aesseily\anaconda3\lib\site-packages (from openmim) (1.4.4)
# Requirement already satisfied: pyyaml in c:\users\v23aesseily\anaconda3\lib\site-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: markdown in c:\users\v23aesseily\anaconda3\lib\site-packages (from model-index->openmim) (3.3.4)
# Collecting ordered-set
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\v23aesseily\anaconda3\lib\site-packages (from pandas->openmim) (2023.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\v23aesseily\anaconda3\lib\site-packages (from pandas->openmim) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\v23aesseily\anaconda3\lib\site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\v23aesseily\anaconda3\lib\site-packages (from requests->openmim) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\v23aesseily\anaconda3\lib\site-packages (from requests->openmim) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\v23aesseily\anaconda3\lib\site-packages (from requests->openmim) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\v23aesseily\anaconda3\lib\site-packages (from requests->openmim) (1.26.11)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from rich->openmim) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\v23aesseily\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\v23aesseily\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->openmim) (1.16.0)
# Installing collected packages: ordered-set, model-index, openmim
# Successfully installed model-index-0.1.11 openmim-0.3.7 ordered-set-4.1.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cpu/torch2.0.0/index.html
# Collecting mmcv-lite
#   Downloading mmcv_lite-2.0.0-py2.py3-none-any.whl (719 kB)
#      ------------------------------------- 719.6/719.6 kB 85.8 kB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\v23aesseily\anaconda3\lib\site-packages (from mmcv-lite) (1.21.5)
# Requirement already satisfied: Pillow in c:\users\v23aesseily\anaconda3\lib\site-packages (from mmcv-lite) (9.2.0)
# Requirement already satisfied: packaging in c:\users\v23aesseily\anaconda3\lib\site-packages (from mmcv-lite) (21.3)
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Collecting mmengine>=0.2.0
#   Downloading mmengine-0.7.4-py3-none-any.whl (374 kB)
#      ------------------------------------- 374.3/374.3 kB 79.0 kB/s eta 0:00:00
# Requirement already satisfied: regex in c:\users\v23aesseily\anaconda3\lib\site-packages (from mmcv-lite) (2022.7.9)
# Requirement already satisfied: yapf in c:\users\v23aesseily\anaconda3\lib\site-packages (from mmcv-lite) (0.31.0)
# Requirement already satisfied: pyyaml in c:\users\v23aesseily\anaconda3\lib\site-packages (from mmcv-lite) (6.0)
# Requirement already satisfied: opencv-python>=3 in c:\users\v23aesseily\anaconda3\lib\site-packages (from mmengine>=0.2.0->mmcv-lite) (4.6.0.66)
# Requirement already satisfied: termcolor in c:\users\v23aesseily\anaconda3\lib\site-packages (from mmengine>=0.2.0->mmcv-lite) (2.3.0)
# Requirement already satisfied: matplotlib in c:\users\v23aesseily\anaconda3\lib\site-packages (from mmengine>=0.2.0->mmcv-lite) (3.5.2)
# Requirement already satisfied: rich in c:\users\v23aesseily\anaconda3\lib\site-packages (from mmengine>=0.2.0->mmcv-lite) (13.4.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\v23aesseily\anaconda3\lib\site-packages (from packaging->mmcv-lite) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\v23aesseily\anaconda3\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv-lite) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv-lite) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\v23aesseily\anaconda3\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv-lite) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\v23aesseily\anaconda3\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv-lite) (0.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from rich->mmengine>=0.2.0->mmcv-lite) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\v23aesseily\anaconda3\lib\site-packages (from rich->mmengine>=0.2.0->mmcv-lite) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\v23aesseily\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.2.0->mmcv-lite) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\v23aesseily\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv-lite) (1.16.0)
# Installing collected packages: addict, mmengine, mmcv-lite
# Successfully installed addict-2.4.0 mmcv-lite-2.0.0 mmengine-0.7.4
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\v23aesseily\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\v23aesseily\anaconda3\lib\site-packages)

# %%
def decode_map(label_mask):
    label_colors = get_card_colormap()
    r = label_mask.copy()
    g = label_mask.copy()
    b = label_mask.copy()
    for ll in range(0, 2):
        r[label_mask == ll] = label_colors[ll, 0]
        g[label_mask == ll] = label_colors[ll, 1]
        b[label_mask == ll] = label_colors[ll, 2]
    rgb = np.zeros((label_mask.shape[0], label_mask.shape[1], 3))
    rgb[:, :, 0] = r
    rgb[:, :, 1] = g
    rgb[:, :, 2] = b

    return rgb.astype(np.uint8)

# %%
def get_card_colormap():
    return np.asarray([[0, 0, 0], [255, 255, 255]])

# %%
def get_cnt(edged, img, ratio):
    kernel = np.ones((3, 3), np.uint8)
    edged = cv2.dilate(edged, kernel, iterations=1)
    mask = np.zeros((edged.shape[0], edged.shape[1]), np.uint8)
    mask[10:edged.shape[0] - 10, 10:edged.shape[1] - 10] = 1
    edged = edged * mask

    cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    # cnts = cnts[0] if imutils.is_cv2() else cnts[1]
    cnts = cnts[0] if imutils.is_cv2(or_better=True) else cnts[1]
    cnts = sorted(cnts, key=lambda c: cv2.arcLength(c, True), reverse=True)
    edgelines = np.zeros(edged.shape, np.uint8)
    cNum = 4

    for i in range(min(cNum, len(cnts))):
        TH = 1 / 20.0
        if cv2.contourArea(cnts[i]) < TH * img.shape[0] * img.shape[1]:
            cv2.drawContours(edgelines, [cnts[i]], 0, (255, 255, 255), -1)
        else:
            cv2.drawContours(edgelines, [cnts[i]], 0, (1, 1, 1), -1)
            edgelines = edgelines * edged
            break
        cv2.drawContours(edgelines, [cnts[i]], 0, (255, 255, 255), -1)

    if debug:
        cv2.imwrite(pjoin(debug_dir, name + "_edgelines.png"), edgelines)

    lines = cv2.HoughLines(edgelines, 1, np.pi / 180, 200)

    if lines is None or len(lines) < 4:
        if debug:
            print("Detection Error: Could not find enough lines (must more than 4) from the detected edge.")
        raise Exception("Lines not found.")

    if debug:
        lines_draw = np.zeros((len(lines), 4), dtype=int)
        img_draw = img.copy()
        for i in range(0, len(lines)):
            rho, theta = lines[i][0][0], lines[i][0][1]
            a = np.cos(theta)
            b = np.sin(theta)
            x0 = a * rho
            y0 = b * rho
            lines_draw[i][0] = int(x0 + 1000 * (-b))
            lines_draw[i][1] = int(y0 + 1000 * (a))
            lines_draw[i][2] = int(x0 - 1000 * (-b))
            lines_draw[i][3] = int(y0 - 1000 * (a))
            cv2.line(img_draw, (lines_draw[i][0], lines_draw[i][1]), (lines_draw[i][2], lines_draw[i][3]), (0, 255, 0),
                     1)
        cv2.imwrite(pjoin(debug_dir, name + '_hough1.png'), img_draw)

    strong_lines = np.zeros([4, 1, 2])
    n2 = 0

    for n1 in range(0, len(lines)):
        if n2 == 4:
            break
        for rho, theta in lines[n1]:
            if n1 == 0:
                strong_lines[n2] = lines[n1]
                n2 = n2 + 1
            else:
                c1 = np.isclose(abs(rho), abs(strong_lines[0:n2, 0, 0]), atol=80)
                c2 = np.isclose(np.pi - theta, strong_lines[0:n2, 0, 1], atol=np.pi / 36)
                c = np.all([c1, c2], axis=0)
                if any(c):
                    continue
                closeness_rho = np.isclose(rho, strong_lines[0:n2, 0, 0], atol=40)
                closeness_theta = np.isclose(theta, strong_lines[0:n2, 0, 1], atol=np.pi / 36)
                closeness = np.all([closeness_rho, closeness_theta], axis=0)
                if not any(closeness) and n2 < 4 and theta != 0:
                    strong_lines[n2] = lines[n1]
                    n2 = n2 + 1

    # draw strong lines
    lines1 = np.zeros((len(strong_lines), 4), dtype=int)
    for i in range(0, len(strong_lines)):
        rho, theta = strong_lines[i][0][0], strong_lines[i][0][1]
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a * rho
        y0 = b * rho
        lines1[i][0] = int(x0 + 1000 * (-b))
        lines1[i][1] = int(y0 + 1000 * (a))
        lines1[i][2] = int(x0 - 1000 * (-b))
        lines1[i][3] = int(y0 - 1000 * (a))

        if debug:
            cv2.line(img, (lines1[i][0], lines1[i][1]), (lines1[i][2], lines1[i][3]), (0, 255, 0), 3)

    approx = np.zeros((len(strong_lines), 1, 2), dtype=int)
    index = 0
    combs = list((combinations(lines1, 2)))
    for twoLines in combs:
        x1, y1, x2, y2 = twoLines[0]
        x3, y3, x4, y4 = twoLines[1]
        [x, y] = cross_point([x1, y1, x2, y2], [x3, y3, x4, y4])
        if 0 < x < img.shape[1] and 0 < y < img.shape[0] and index < 4:
            cv2.circle(img, (int(x), int(y)), 5, (0, 0, 255), 3)
            approx[index] = (int(x), int(y))
            index = index + 1

    if debug:
        cv2.imwrite(pjoin(debug_dir, name + '_hough2.png'), img)

    if checked_valid_transform(approx):
        return approx * ratio

# %%
def cross_point(line1, line2):
    x = 0
    y = 0
    x1 = line1[0]
    y1 = line1[1]
    x2 = line1[2]
    y2 = line1[3]
    x3 = line2[0]
    y3 = line2[1]
    x4 = line2[2]
    y4 = line2[3]
    if (x2 - x1) == 0:
        k1 = None
    else:
        k1 = (y2 - y1) * 1.0 / (x2 - x1)
        b1 = y1 * 1.0 - x1 * k1 * 1.0
    if (x4 - x3) == 0:
        k2 = None
        b2 = 0
    else:
        k2 = (y4 - y3) * 1.0 / (x4 - x3)
        b2 = y3 * 1.0 - x3 * k2 * 1.0
    if k1 is None:
        if not k2 is None:
            x = x1
            y = k2 * x1 + b2
    elif k2 is None:
        x = x3
        y = k1 * x3 + b1
    elif not k2 == k1:
        x = (b2 - b1) * 1.0 / (k1 - k2)
        y = k1 * x * 1.0 + b1 * 1.0

    return [x, y]

# %%
def checked_valid_transform(approx):
    hull = cv2.convexHull(approx)
    TH_ANGLE = 45
    if len(hull) == 4:
        for i in range(4):
            p1 = hull[(i - 1) % 4]
            p2 = hull[i]
            p3 = hull[(i + 1) % 4]
            angel = get_angle(p1, p2, p3)
            if 90 - TH_ANGLE < angel < 90 + TH_ANGLE:
                continue
            else:
                if debug:
                    print("Detection Error: The detected corners could not form a valid quadrilateral for transformation.")
                raise Exception("Corner points invalid.")from None
    else:
        if debug:
            print("Detection Error: Could not find four corners from the detected edge.")
        raise Exception("Corner points less than 4.")from None

    return True

# %%
def get_angle(sta_point, mid_point, end_point):
    ma_x = sta_point[0][0] - mid_point[0][0]
    ma_y = sta_point[0][1] - mid_point[0][1]
    mb_x = end_point[0][0] - mid_point[0][0]
    mb_y = end_point[0][1] - mid_point[0][1]
    ab_x = sta_point[0][0] - end_point[0][0]
    ab_y = sta_point[0][1] - end_point[0][1]
    ab_val2 = ab_x * ab_x + ab_y * ab_y
    ma_val2 = ma_x * ma_x + ma_y * ma_y
    mb_val2 = mb_x * mb_x + mb_y * mb_y
    cos_M = (ma_val2 + mb_val2 - ab_val2) / (2 * np.sqrt(ma_val2) * np.sqrt(mb_val2))
    angleAMB = np.arccos(cos_M) / np.pi * 180
    return angleAMB

# %%
def finetune(img, ratio):
    offset = int(2 * ratio)
    img = img[offset + 15:img.shape[0] - offset,
          int(offset * 2):img.shape[1] - int(offset * 2), :]
    if img.shape[0] < img.shape[1]:
        img = cv2.resize(img, (img.shape[1], int(img.shape[1] / 856 * 540)))
        r = int(img.shape[1] / 856 * 31.8)
    else:
        img = cv2.resize(img, (img.shape[1], int(img.shape[1] / 540 * 856)))
        r = int(img.shape[1] / 540 * 31.8)
    img = set_corner(img, r)
    if img.shape[0] > img.shape[1]:
        img = cv2.transpose(img)
        img = cv2.flip(img, 0)
    return img

# %%
def set_corner(img, r):
    b_channel, g_channel, r_channel = cv2.split(img)
    alpha_channel = np.ones(b_channel.shape, dtype=b_channel.dtype) * 255
    row = img.shape[0]
    col = img.shape[1]

    for i in range(0, r):
        for j in range(0, r):
            if (r - i) * (r - i) + (r - j) * (r - j) > r * r:
                alpha_channel[i][j] = 0

    for i in range(0, r):
        for j in range(col - r, col):
            if (r - i) * (r - i) + (r - col + j + 1) * (r - col + j + 1) > r * r:
                alpha_channel[i][j] = 0

    for i in range(row - r, row):
        for j in range(0, r):
            if (r - row + i + 1) * (r - row + i + 1) + (r - j) * (r - j) > r * r:
                alpha_channel[i][j] = 0

    for i in range(row - r, row):
        for j in range(col - r, col):
            if (r - row + i + 1) * (r - row + i + 1) + (r - col + j + 1) * (r - col + j + 1) > r * r:
                alpha_channel[i][j] = 0

    img_bgra = cv2.merge((b_channel, g_channel, r_channel, alpha_channel))

    return img_bgra

# %%
def detect_edge(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX)

    mean_gray = cv2.mean(gray)
    TH_LIGHT = 150
    if mean_gray[0] > TH_LIGHT:
        gray = exposure.adjust_gamma(gray, gamma=6)
        gray = exposure.equalize_adapthist(gray, kernel_size=None, clip_limit=0.02)
        gray = img_as_ubyte(gray)

    kernel = np.ones((15, 15), np.uint8)
    closing = cv2.morphologyEx(gray, cv2.MORPH_CLOSE, kernel)
    blurred = cv2.medianBlur(closing, 5)
    blurred = cv2.bilateralFilter(blurred, d=0, sigmaColor=15, sigmaSpace=10)

    edged = cv2.Canny(blurred, 75, 200)

    if debug:
        cv2.imwrite(pjoin(debug_dir, name + "_Cannyedge.png"), edged)

    return edged

# %%
def AprroxmateContour(thresh):
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)
    for eps in np.linspace(0.001, 0.05, 10):
        peri = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, eps * peri, True)
        if len(approx) ==4:
            break
    if len(approx) !=4 :
        raise Exception("Lines not found.")
    return approx

# %%
Model =CreateModel()
Model.load_weights("best_model.hdf5")

# %%
dir_path = "PDV_Output_Batch_MSISDNs"
list_of_pdfs = os.listdir(dir_path)
print(len)
index = 0
for pdf in list_of_pdfs:
    path_of_pdf = os.path.join(dir_path , pdf)
    images = convert_from_path(path_of_pdf, 500 ,poppler_path = r".\poppler-0.68.0\bin")
    for i, image in enumerate(images):
        Imagesize = image.size
        ImageInput= PrepareImage(image)
        Predicted = np.where(Model.predict(ImageInput) > 0.4  , 255 ,0)
        MaskPredicted = np.array(np.squeeze(Predicted[0]) , dtype='uint8')
        MaskPredicted = cv2.resize(MaskPredicted, (Imagesize[1], Imagesize[0]), interpolation=cv2.INTER_LINEAR)
        elements_count = collections.Counter(Predicted[0].reshape(1 ,256*256 )[0])
        print(elements_count[255])
        if elements_count[255] > 350:
            fname = 'imagesPdf\image'+str(i)+str(index)+'.png'
            
        else:
            fname = 'Contract\image'+str(i)+str(index)+'.png'
        print(fname)
        index += 1 
        image.save(fname, "PNG")
# Out:
# <built-in function len>
# 1/1 [==============================] - 3s 3s/step
# 4973
# imagesPdf\image00.png
# 1/1 [==============================] - 1s 656ms/step
# 1556
# imagesPdf\image11.png
# 1/1 [==============================] - 1s 558ms/step
# 16
# Contract\image22.png
# 1/1 [==============================] - 1s 644ms/step
# 5068
# imagesPdf\image03.png
# 1/1 [==============================] - 1s 571ms/step
# 4294
# imagesPdf\image14.png
# 1/1 [==============================] - 1s 575ms/step
# 4772
# imagesPdf\image05.png
# 1/1 [==============================] - 1s 703ms/step
# 2611
# imagesPdf\image16.png
# 1/1 [==============================] - 1s 668ms/step
# 4782
# imagesPdf\image07.png
# 1/1 [==============================] - 1s 691ms/step
# 0
# Contract\image18.png
# 1/1 [==============================] - 1s 568ms/step
# 4868
# imagesPdf\image09.png
# 1/1 [==============================] - 1s 743ms/step
# 1020
# imagesPdf\image110.png
# 1/1 [==============================] - 1s 586ms/step
# 0
# Contract\image211.png
# 1/1 [==============================] - 1s 634ms/step
# 4716
# imagesPdf\image012.png
# 1/1 [==============================] - 1s 599ms/step
# 2977
# imagesPdf\image113.png
# 1/1 [==============================] - 1s 537ms/step
# 1940
# imagesPdf\image014.png
# 1/1 [==============================] - 1s 619ms/step
# 0
# Contract\image115.png
# 1/1 [==============================] - 1s 657ms/step
# 0
# Contract\image216.png
# 1/1 [==============================] - 1s 584ms/step
# 1967
# imagesPdf\image017.png
# 1/1 [==============================] - 1s 648ms/step
# 5010
# imagesPdf\image118.png
# 1/1 [==============================] - 1s 638ms/step
# 4761
# imagesPdf\image019.png
# 1/1 [==============================] - 1s 618ms/step
# 0
# Contract\image120.png
# 1/1 [==============================] - 1s 709ms/step
# 6322
# imagesPdf\image021.png
# 1/1 [==============================] - 1s 565ms/step
# 4941
# imagesPdf\image022.png
# 1/1 [==============================] - 1s 610ms/step
# 2368
# imagesPdf\image123.png
# 1/1 [==============================] - 1s 526ms/step
# 4945
# imagesPdf\image024.png
# 1/1 [==============================] - 1s 545ms/step
# 2722
# imagesPdf\image125.png
# 1/1 [==============================] - 1s 615ms/step
# 195
# Contract\image226.png
# 1/1 [==============================] - 1s 536ms/step
# 4803
# imagesPdf\image027.png
# 1/1 [==============================] - 1s 555ms/step
# 412
# imagesPdf\image128.png
# 1/1 [==============================] - 1s 585ms/step
# 6133
# imagesPdf\image029.png
# 1/1 [==============================] - 1s 625ms/step
# 4987
# imagesPdf\image030.png
# 1/1 [==============================] - 1s 684ms/step
# 816
# imagesPdf\image131.png
# 1/1 [==============================] - 1s 609ms/step
# 5006
# imagesPdf\image032.png
# 1/1 [==============================] - 1s 622ms/step
# 2027
# imagesPdf\image133.png
# 1/1 [==============================] - 1s 567ms/step
# 0
# Contract\image034.png
# 1/1 [==============================] - 1s 535ms/step
# 5027
# imagesPdf\image035.png
# 1/1 [==============================] - 1s 526ms/step
# 1372
# imagesPdf\image136.png
# 1/1 [==============================] - 1s 554ms/step
# 5020
# imagesPdf\image037.png
# 1/1 [==============================] - 1s 635ms/step
# 1013
# imagesPdf\image138.png
# 1/1 [==============================] - 1s 649ms/step
# 0
# Contract\image039.png
# 1/1 [==============================] - 1s 545ms/step
# 0
# Contract\image040.png
# 1/1 [==============================] - 1s 559ms/step
# 21
# Contract\image141.png
# 1/1 [==============================] - 1s 573ms/step
# 6
# Contract\image242.png
# 1/1 [==============================] - 1s 602ms/step
# 9
# Contract\image343.png
# 1/1 [==============================] - 1s 616ms/step
# 3
# Contract\image444.png
# 1/1 [==============================] - 1s 594ms/step
# 6
# Contract\image545.png
# 1/1 [==============================] - 1s 672ms/step
# 0
# Contract\image646.png
# 1/1 [==============================] - 1s 627ms/step
# 0
# Contract\image747.png
# 1/1 [==============================] - 1s 548ms/step
# 0
# Contract\image848.png
# 1/1 [==============================] - 1s 590ms/step
# 0
# Contract\image949.png
# 1/1 [==============================] - 1s 585ms/step
# 5114
# imagesPdf\image050.png
# 1/1 [==============================] - 1s 546ms/step
# 0
# Contract\image151.png
# 1/1 [==============================] - 1s 617ms/step
# 0
# Contract\image252.png
# 1/1 [==============================] - 1s 622ms/step
# 5027
# imagesPdf\image053.png
# 1/1 [==============================] - 1s 767ms/step
# 1372
# imagesPdf\image154.png
# 1/1 [==============================] - 1s 588ms/step
# 0
# Contract\image055.png
# 1/1 [==============================] - 1s 562ms/step
# 0
# Contract\image056.png
# 1/1 [==============================] - 1s 608ms/step
# 21
# Contract\image157.png
# 1/1 [==============================] - 1s 577ms/step
# 6
# Contract\image258.png
# 1/1 [==============================] - 1s 595ms/step
# 9
# Contract\image359.png
# 1/1 [==============================] - 1s 606ms/step
# 3
# Contract\image460.png
# 1/1 [==============================] - 1s 699ms/step
# 6
# Contract\image561.png
# 1/1 [==============================] - 1s 549ms/step
# 0
# Contract\image662.png
# 1/1 [==============================] - 1s 661ms/step
# 0
# Contract\image763.png
# 1/1 [==============================] - 1s 549ms/step
# 0
# Contract\image864.png
# 1/1 [==============================] - 1s 626ms/step
# 0
# Contract\image965.png
# 1/1 [==============================] - 1s 594ms/step
# 5020
# imagesPdf\image066.png
# 1/1 [==============================] - 1s 591ms/step
# 1013
# imagesPdf\image167.png
# 1/1 [==============================] - 1s 523ms/step
# 0
# Contract\image068.png
# 1/1 [==============================] - 1s 559ms/step
# 4774
# imagesPdf\image069.png
# 1/1 [==============================] - 1s 562ms/step
# 0
# Contract\image170.png
# 1/1 [==============================] - 1s 619ms/step
# 5084
# imagesPdf\image071.png
# 1/1 [==============================] - 0s 496ms/step
# 3801
# imagesPdf\image172.png
# 1/1 [==============================] - 1s 559ms/step
# 5084
# imagesPdf\image073.png
# 1/1 [==============================] - 1s 619ms/step
# 3801
# imagesPdf\image174.png
# 1/1 [==============================] - 1s 567ms/step
# 5756
# imagesPdf\image075.png
# 1/1 [==============================] - 1s 602ms/step
# 5756
# imagesPdf\image076.png
# 1/1 [==============================] - 1s 573ms/step
# 2266
# imagesPdf\image077.png
# 1/1 [==============================] - 1s 582ms/step
# 5071
# imagesPdf\image178.png
# 1/1 [==============================] - 1s 607ms/step
# 0
# Contract\image079.png
# 1/1 [==============================] - 1s 508ms/step
# 0
# Contract\image180.png
# 1/1 [==============================] - 1s 597ms/step
# 0
# Contract\image281.png
# 1/1 [==============================] - 1s 582ms/step
# 0
# Contract\image382.png
# 1/1 [==============================] - 1s 611ms/step
# 0
# Contract\image483.png
# 1/1 [==============================] - 1s 634ms/step
# 0
# Contract\image584.png
# 1/1 [==============================] - 1s 534ms/step
# 0
# Contract\image685.png
# 1/1 [==============================] - 1s 524ms/step
# 0
# Contract\image786.png
# 1/1 [==============================] - 1s 519ms/step
# 0
# Contract\image887.png
# 1/1 [==============================] - 1s 598ms/step
# 0
# Contract\image988.png
# 1/1 [==============================] - 0s 485ms/step
# 5756
# imagesPdf\image089.png
# 1/1 [==============================] - 1s 604ms/step
# 0
# Contract\image090.png
# 1/1 [==============================] - 1s 597ms/step
# 0
# Contract\image191.png
# 1/1 [==============================] - 1s 601ms/step
# 0
# Contract\image292.png
# 1/1 [==============================] - 0s 495ms/step
# 0
# Contract\image393.png
# 1/1 [==============================] - 0s 489ms/step
# 0
# Contract\image494.png
# 1/1 [==============================] - 1s 600ms/step
# 0
# Contract\image595.png
# 1/1 [==============================] - 1s 589ms/step
# 0
# Contract\image696.png
# 1/1 [==============================] - 1s 573ms/step
# 0
# Contract\image797.png
# 1/1 [==============================] - 1s 603ms/step
# 0
# Contract\image898.png
# 1/1 [==============================] - 1s 600ms/step
# 0
# Contract\image999.png
# 1/1 [==============================] - 0s 396ms/step
# 7
# Contract\image0100.png
# 1/1 [==============================] - 0s 455ms/step
# 336
# Contract\image0101.png
# 1/1 [==============================] - 0s 454ms/step
# 5020
# imagesPdf\image0102.png
# 1/1 [==============================] - 0s 386ms/step
# 1013
# imagesPdf\image1103.png
# 1/1 [==============================] - 0s 462ms/step
# 5018
# imagesPdf\image0104.png
# 1/1 [==============================] - 1s 506ms/step
# 0
# Contract\image1105.png
# 1/1 [==============================] - 0s 445ms/step
# 4818
# imagesPdf\image0106.png
# 1/1 [==============================] - 0s 472ms/step
# 1587
# imagesPdf\image1107.png
# 1/1 [==============================] - 0s 469ms/step
# 6472
# imagesPdf\image0108.png
# 1/1 [==============================] - 0s 484ms/step
# 0
# Contract\image0109.png
# 1/1 [==============================] - 0s 478ms/step
# 0
# Contract\image1110.png
# 1/1 [==============================] - 1s 653ms/step
# 0
# Contract\image2111.png
# 1/1 [==============================] - 1s 681ms/step
# 0
# Contract\image3112.png
# 1/1 [==============================] - 1s 592ms/step
# 0
# Contract\image4113.png
# 1/1 [==============================] - 1s 880ms/step
# 0
# Contract\image5114.png
# 1/1 [==============================] - 1s 735ms/step
# 0
# Contract\image6115.png
# 1/1 [==============================] - 1s 633ms/step
# 0
# Contract\image7116.png
# 1/1 [==============================] - 1s 584ms/step
# 0
# Contract\image8117.png
# 1/1 [==============================] - 1s 579ms/step
# 0
# Contract\image9118.png
# 1/1 [==============================] - 1s 619ms/step
# 4727
# imagesPdf\image0119.png
# 1/1 [==============================] - 1s 631ms/step
# 0
# Contract\image1120.png
# 1/1 [==============================] - 1s 610ms/step
# 5020
# imagesPdf\image0121.png
# 1/1 [==============================] - 1s 586ms/step
# 1013
# imagesPdf\image1122.png
# 1/1 [==============================] - 1s 667ms/step
# 0
# Contract\image0123.png
# 1/1 [==============================] - 1s 547ms/step
# 336
# Contract\image0124.png
# 1/1 [==============================] - 1s 603ms/step
# 4780
# imagesPdf\image0125.png
# 1/1 [==============================] - 1s 544ms/step
# 0
# Contract\image1126.png
# 1/1 [==============================] - 1s 600ms/step
# 4973
# imagesPdf\image0127.png
# 1/1 [==============================] - 1s 635ms/step
# 1556
# imagesPdf\image1128.png
# 1/1 [==============================] - 1s 528ms/step
# 17
# Contract\image2129.png
# 1/1 [==============================] - 0s 497ms/step
# 2
# Contract\image0130.png
# 1/1 [==============================] - 0s 493ms/step
# 4741
# imagesPdf\image0131.png
# 1/1 [==============================] - 0s 464ms/step
# 8
# Contract\image1132.png
# 1/1 [==============================] - 1s 598ms/step
# 5041
# imagesPdf\image0133.png
# 1/1 [==============================] - 1s 505ms/step
# 0
# Contract\image1134.png
# 1/1 [==============================] - 1s 532ms/step
# 5025
# imagesPdf\image0135.png
# 1/1 [==============================] - 1s 513ms/step
# 3679
# imagesPdf\image1136.png
# 1/1 [==============================] - 1s 634ms/step
# 6670
# imagesPdf\image0137.png
# 1/1 [==============================] - 1s 552ms/step
# 0
# Contract\image1138.png
# 1/1 [==============================] - 1s 514ms/step
# 4792
# imagesPdf\image0139.png
# 1/1 [==============================] - 1s 610ms/step
# 0
# Contract\image1140.png
# 1/1 [==============================] - 1s 573ms/step
# 4758
# imagesPdf\image0141.png
# 1/1 [==============================] - 1s 528ms/step
# 3753
# imagesPdf\image1142.png
# 1/1 [==============================] - 0s 471ms/step
# 5127
# imagesPdf\image0143.png
# 1/1 [==============================] - 1s 518ms/step
# 2757
# imagesPdf\image1144.png
# 1/1 [==============================] - 1s 572ms/step
# 4901
# imagesPdf\image0145.png
# 1/1 [==============================] - 0s 499ms/step
# 2827
# imagesPdf\image1146.png
# 1/1 [==============================] - 1s 603ms/step
# 4980
# imagesPdf\image0147.png
# 1/1 [==============================] - 1s 643ms/step
# 203
# Contract\image1148.png
# 1/1 [==============================] - 1s 586ms/step
# 2143
# imagesPdf\image0149.png
# 1/1 [==============================] - 1s 589ms/step
# 4729
# imagesPdf\image1150.png
# 1/1 [==============================] - 1s 761ms/step
# 0
# Contract\image2151.png
# 1/1 [==============================] - 1s 524ms/step
# 4939
# imagesPdf\image0152.png
# 1/1 [==============================] - 1s 590ms/step
# 2114
# imagesPdf\image1153.png
# 1/1 [==============================] - 1s 527ms/step
# 1
# Contract\image2154.png
# 1/1 [==============================] - 1s 593ms/step
# 4761
# imagesPdf\image0155.png
# 1/1 [==============================] - 1s 576ms/step
# 0
# Contract\image1156.png
# 1/1 [==============================] - 1s 526ms/step
# 5006
# imagesPdf\image0157.png
# 1/1 [==============================] - 1s 619ms/step
# 2448
# imagesPdf\image1158.png
# 1/1 [==============================] - 1s 587ms/step
# 5007
# imagesPdf\image0159.png
# 1/1 [==============================] - 1s 555ms/step
# 2786
# imagesPdf\image1160.png
# 1/1 [==============================] - 1s 504ms/step
# 22
# Contract\image2161.png
# 1/1 [==============================] - 1s 560ms/step
# 4780
# imagesPdf\image0162.png
# 1/1 [==============================] - 0s 499ms/step
# 4806
# imagesPdf\image0163.png
# 1/1 [==============================] - 1s 550ms/step
# 3577
# imagesPdf\image1164.png
# 1/1 [==============================] - 1s 583ms/step
# 4781
# imagesPdf\image0165.png
# 1/1 [==============================] - 1s 608ms/step
# 804
# imagesPdf\image1166.png
# 1/1 [==============================] - 1s 587ms/step
# 5201
# imagesPdf\image0167.png
# 1/1 [==============================] - 1s 534ms/step
# 2923
# imagesPdf\image1168.png
# 1/1 [==============================] - 1s 553ms/step
# 4978
# imagesPdf\image0169.png
# 1/1 [==============================] - 1s 534ms/step
# 3346
# imagesPdf\image1170.png
# 1/1 [==============================] - 1s 541ms/step
# 5010
# imagesPdf\image0171.png
# 1/1 [==============================] - 0s 497ms/step
# 1991
# imagesPdf\image1172.png
# 1/1 [==============================] - 1s 600ms/step
# 4997
# imagesPdf\image0173.png
# 1/1 [==============================] - 1s 719ms/step
# 2880
# imagesPdf\image1174.png
# 1/1 [==============================] - 1s 511ms/step
# 5097
# imagesPdf\image0175.png
# 1/1 [==============================] - 1s 574ms/step
# 2918
# imagesPdf\image1176.png
# 1/1 [==============================] - 1s 519ms/step
# 0
# Contract\image0177.png
# 1/1 [==============================] - 0s 493ms/step
# 4815
# imagesPdf\image1178.png
# 1/1 [==============================] - 0s 498ms/step
# 4980
# imagesPdf\image0179.png
# 1/1 [==============================] - 1s 624ms/step
# 203
# Contract\image1180.png
# 1/1 [==============================] - 1s 500ms/step
# 4832
# imagesPdf\image0181.png
# 1/1 [==============================] - 1s 595ms/step
# 0
# Contract\image1182.png
# 1/1 [==============================] - 1s 569ms/step
# 4803
# imagesPdf\image0183.png
# 1/1 [==============================] - 0s 491ms/step
# 412
# imagesPdf\image1184.png
# 1/1 [==============================] - 1s 537ms/step
# 2266
# imagesPdf\image0185.png
# 1/1 [==============================] - 1s 593ms/step
# 5071
# imagesPdf\image1186.png
# 1/1 [==============================] - 1s 555ms/step
# 5040
# imagesPdf\image0187.png
# 1/1 [==============================] - 1s 580ms/step
# 2255
# imagesPdf\image1188.png
# 1/1 [==============================] - 0s 468ms/step
# 4801
# imagesPdf\image0189.png
# 1/1 [==============================] - 1s 588ms/step
# 2219
# imagesPdf\image1190.png
# 1/1 [==============================] - 1s 573ms/step
# 5324
# imagesPdf\image0191.png
# 1/1 [==============================] - 1s 603ms/step
# 0
# Contract\image1192.png
# 1/1 [==============================] - 1s 654ms/step
# 4916
# imagesPdf\image0193.png
# 1/1 [==============================] - 1s 508ms/step
# 3782
# imagesPdf\image1194.png
# 1/1 [==============================] - 1s 541ms/step
# 7563
# imagesPdf\image0195.png
# 1/1 [==============================] - 1s 640ms/step
# 450
# imagesPdf\image1196.png
# 1/1 [==============================] - 1s 503ms/step
# 4941
# imagesPdf\image0197.png
# 1/1 [==============================] - 0s 494ms/step
# 2368
# imagesPdf\image1198.png
# 1/1 [==============================] - 1s 593ms/step
# 5370
# imagesPdf\image0199.png
# 1/1 [==============================] - 1s 593ms/step
# 5050
# imagesPdf\image1200.png
# 1/1 [==============================] - 1s 556ms/step
# 0
# Contract\image2201.png
# 1/1 [==============================] - 1s 538ms/step
# 5092
# imagesPdf\image0202.png
# 1/1 [==============================] - 1s 593ms/step
# 815
# imagesPdf\image1203.png
# 1/1 [==============================] - 1s 591ms/step
# 4974
# imagesPdf\image0204.png
# 1/1 [==============================] - 1s 560ms/step
# 1674
# imagesPdf\image1205.png
# 1/1 [==============================] - 1s 609ms/step
# 0
# Contract\image2206.png
# 1/1 [==============================] - 1s 505ms/step
# 4752
# imagesPdf\image0207.png
# 1/1 [==============================] - 1s 635ms/step
# 30
# Contract\image1208.png
# 1/1 [==============================] - 1s 602ms/step
# 5210
# imagesPdf\image0209.png
# 1/1 [==============================] - 1s 585ms/step
# 3173
# imagesPdf\image1210.png
# 1/1 [==============================] - 1s 604ms/step
# 2980
# imagesPdf\image0211.png
# 1/1 [==============================] - 1s 608ms/step
# 912
# imagesPdf\image1212.png
# 1/1 [==============================] - 1s 558ms/step
# 6217
# imagesPdf\image0213.png
# 1/1 [==============================] - 1s 636ms/step
# 5077
# imagesPdf\image0214.png
# 1/1 [==============================] - 1s 666ms/step
# 0
# Contract\image1215.png
# 1/1 [==============================] - 1s 595ms/step
# 20
# Contract\image2216.png
# 1/1 [==============================] - 1s 613ms/step
# 7410
# imagesPdf\image0217.png
# 1/1 [==============================] - 1s 553ms/step
# 0
# Contract\image1218.png
# 1/1 [==============================] - 1s 566ms/step
# 5121
# imagesPdf\image0219.png
# 1/1 [==============================] - 1s 597ms/step
# 2548
# imagesPdf\image1220.png
# 1/1 [==============================] - 1s 607ms/step
# 4780
# imagesPdf\image0221.png
# 1/1 [==============================] - 1s 581ms/step
# 4780
# imagesPdf\image0222.png
# 1/1 [==============================] - 1s 553ms/step
# 4754
# imagesPdf\image0223.png
# 1/1 [==============================] - 0s 497ms/step
# 385
# imagesPdf\image1224.png
# 1/1 [==============================] - 1s 510ms/step
# 5008
# imagesPdf\image0225.png
# 1/1 [==============================] - 1s 549ms/step
# 5432
# imagesPdf\image1226.png
# 1/1 [==============================] - 1s 568ms/step
# 5060
# imagesPdf\image0227.png
# 1/1 [==============================] - 1s 507ms/step
# 0
# Contract\image1228.png
# 1/1 [==============================] - 1s 608ms/step
# 0
# Contract\image2229.png
# 1/1 [==============================] - 1s 598ms/step
# 4974
# imagesPdf\image0230.png
# 1/1 [==============================] - 1s 529ms/step
# 1674
# imagesPdf\image1231.png
# 1/1 [==============================] - 1s 562ms/step
# 0
# Contract\image2232.png
# 1/1 [==============================] - 1s 569ms/step
# 3052
# imagesPdf\image0233.png
# 1/1 [==============================] - 1s 509ms/step
# 4751
# imagesPdf\image1234.png
# 1/1 [==============================] - 1s 521ms/step
# 0
# Contract\image2235.png
# 1/1 [==============================] - 1s 519ms/step
# 5048
# imagesPdf\image0236.png
# 1/1 [==============================] - 1s 508ms/step
# 1594
# imagesPdf\image1237.png
# 1/1 [==============================] - 1s 546ms/step
# 15
# Contract\image2238.png
# 1/1 [==============================] - 1s 547ms/step
# 4795
# imagesPdf\image0239.png
# 1/1 [==============================] - 1s 593ms/step
# 1165
# imagesPdf\image1240.png
# 1/1 [==============================] - 1s 578ms/step
# 0
# Contract\image2241.png
# 1/1 [==============================] - 1s 592ms/step
# 4901
# imagesPdf\image0242.png
# 1/1 [==============================] - 1s 591ms/step
# 2999
# imagesPdf\image1243.png
# 1/1 [==============================] - 1s 594ms/step
# 23
# Contract\image2244.png
# 1/1 [==============================] - 1s 640ms/step
# 5047
# imagesPdf\image0245.png
# 1/1 [==============================] - 1s 612ms/step
# 4037
# imagesPdf\image1246.png
# 1/1 [==============================] - 1s 616ms/step
# 0
# Contract\image0247.png
# 1/1 [==============================] - 1s 554ms/step
# 4955
# imagesPdf\image0248.png
# 1/1 [==============================] - 1s 557ms/step
# 3193
# imagesPdf\image1249.png
# 1/1 [==============================] - 1s 556ms/step
# 3755
# imagesPdf\image0250.png
# 1/1 [==============================] - 1s 538ms/step
# 4945
# imagesPdf\image1251.png
# 1/1 [==============================] - 0s 492ms/step
# 5029
# imagesPdf\image0252.png
# 1/1 [==============================] - 1s 556ms/step
# 3079
# imagesPdf\image1253.png
# 1/1 [==============================] - 1s 527ms/step
# 4741
# imagesPdf\image0254.png
# 1/1 [==============================] - 1s 624ms/step
# 8
# Contract\image1255.png
# 1/1 [==============================] - 0s 497ms/step
# 0
# Contract\image0256.png
# 1/1 [==============================] - 1s 587ms/step
# 146
# Contract\image0257.png
# 1/1 [==============================] - 1s 507ms/step
# 4777
# imagesPdf\image0258.png
# 1/1 [==============================] - 1s 596ms/step
# 0
# Contract\image1259.png
# 1/1 [==============================] - 1s 587ms/step
# 0
# Contract\image2260.png
# 1/1 [==============================] - 1s 555ms/step
# 5157
# imagesPdf\image0261.png
# 1/1 [==============================] - 1s 610ms/step
# 2337
# imagesPdf\image1262.png
# 1/1 [==============================] - 1s 599ms/step
# 5969
# imagesPdf\image0263.png
# 1/1 [==============================] - 1s 542ms/step
# 0
# Contract\image1264.png
# 1/1 [==============================] - 1s 605ms/step
# 0
# Contract\image2265.png
# 1/1 [==============================] - 1s 620ms/step
# 1298
# imagesPdf\image0266.png
# 1/1 [==============================] - 1s 764ms/step
# 4725
# imagesPdf\image1267.png
# 1/1 [==============================] - 1s 634ms/step
# 4840
# imagesPdf\image0268.png
# 1/1 [==============================] - 1s 616ms/step
# 49
# Contract\image1269.png
# 1/1 [==============================] - 1s 662ms/step
# 4911
# imagesPdf\image0270.png
# 1/1 [==============================] - 1s 566ms/step
# 2964
# imagesPdf\image1271.png
# 1/1 [==============================] - 1s 627ms/step
# 0
# Contract\image0272.png
# 1/1 [==============================] - 1s 593ms/step
# 6133
# imagesPdf\image0273.png
# 1/1 [==============================] - 1s 563ms/step
# 4980
# imagesPdf\image0274.png
# 1/1 [==============================] - 1s 532ms/step
# 1859
# imagesPdf\image1275.png
# 1/1 [==============================] - 1s 627ms/step
# 303
# Contract\image2276.png
# 1/1 [==============================] - 1s 609ms/step
# 1
# Contract\image0277.png
# 1/1 [==============================] - 1s 554ms/step
# 5087
# imagesPdf\image0278.png
# 1/1 [==============================] - 1s 573ms/step
# 3174
# imagesPdf\image1279.png
# 1/1 [==============================] - 1s 657ms/step
# 0
# Contract\image2280.png
# 1/1 [==============================] - 1s 594ms/step
# 4982
# imagesPdf\image0281.png
# 1/1 [==============================] - 1s 563ms/step
# 2412
# imagesPdf\image1282.png
# 1/1 [==============================] - 1s 616ms/step
# 1
# Contract\image2283.png
# 1/1 [==============================] - 1s 622ms/step
# 1298
# imagesPdf\image0284.png
# 1/1 [==============================] - 1s 683ms/step
# 4725
# imagesPdf\image1285.png
# 1/1 [==============================] - 1s 608ms/step
# 4957
# imagesPdf\image0286.png
# 1/1 [==============================] - 1s 652ms/step
# 2186
# imagesPdf\image1287.png
# 1/1 [==============================] - 1s 587ms/step
# 0
# Contract\image0288.png
# 1/1 [==============================] - 1s 565ms/step
# 4794
# imagesPdf\image1289.png
# 1/1 [==============================] - 1s 543ms/step
# 4696
# imagesPdf\image0290.png
# 1/1 [==============================] - 1s 556ms/step
# 664
# imagesPdf\image1291.png
# 1/1 [==============================] - 1s 556ms/step
# 5010
# imagesPdf\image0292.png
# 1/1 [==============================] - 1s 640ms/step
# 1882
# imagesPdf\image1293.png
# 1/1 [==============================] - 1s 576ms/step
# 0
# Contract\image0294.png
# 1/1 [==============================] - 1s 524ms/step
# 4982
# imagesPdf\image0295.png
# 1/1 [==============================] - 1s 602ms/step
# 2412
# imagesPdf\image1296.png
# 1/1 [==============================] - 1s 649ms/step
# 10
# Contract\image2297.png
# 1/1 [==============================] - 1s 503ms/step
# 5268
# imagesPdf\image0298.png
# 1/1 [==============================] - 1s 561ms/step
# 0
# Contract\image1299.png
# 1/1 [==============================] - 1s 545ms/step
# 5024
# imagesPdf\image0300.png
# 1/1 [==============================] - 1s 742ms/step
# 2115
# imagesPdf\image1301.png
# 1/1 [==============================] - 1s 600ms/step
# 6218
# imagesPdf\image0302.png
# 1/1 [==============================] - 0s 469ms/step
# 0
# Contract\image1303.png
# 1/1 [==============================] - 1s 562ms/step
# 4829
# imagesPdf\image0304.png
# 1/1 [==============================] - 1s 597ms/step
# 306
# Contract\image1305.png
# 1/1 [==============================] - 1s 595ms/step
# 4792
# imagesPdf\image0306.png
# 1/1 [==============================] - 0s 488ms/step
# 1964
# imagesPdf\image1307.png
# 1/1 [==============================] - 1s 599ms/step
# 4801
# imagesPdf\image0308.png
# 1/1 [==============================] - 1s 508ms/step
# 1168
# imagesPdf\image1309.png
# 1/1 [==============================] - 1s 583ms/step
# 6133
# imagesPdf\image0310.png
# 1/1 [==============================] - 1s 565ms/step
# 4731
# imagesPdf\image0311.png
# 1/1 [==============================] - 1s 576ms/step
# 318
# Contract\image1312.png
# 1/1 [==============================] - 1s 577ms/step
# 4979
# imagesPdf\image0313.png
# 1/1 [==============================] - 1s 573ms/step
# 1759
# imagesPdf\image1314.png
# 1/1 [==============================] - 1s 500ms/step
# 4973
# imagesPdf\image0315.png
# 1/1 [==============================] - 1s 582ms/step
# 1556
# imagesPdf\image1316.png
# 1/1 [==============================] - 0s 490ms/step
# 0
# Contract\image2317.png
# 1/1 [==============================] - 1s 561ms/step
# 4780
# imagesPdf\image0318.png
# 1/1 [==============================] - 0s 499ms/step
# 0
# Contract\image0319.png
# 1/1 [==============================] - 1s 539ms/step
# 4729
# imagesPdf\image1320.png
# 1/1 [==============================] - 1s 606ms/step
# 0
# Contract\image2321.png
# 1/1 [==============================] - 1s 692ms/step
# 5049
# imagesPdf\image0322.png
# 1/1 [==============================] - 1s 700ms/step
# 3561
# imagesPdf\image1323.png
# 1/1 [==============================] - 1s 578ms/step
# 0
# Contract\image0324.png
# 1/1 [==============================] - 1s 595ms/step
# 5010
# imagesPdf\image0325.png
# 1/1 [==============================] - 1s 589ms/step
# 1991
# imagesPdf\image1326.png
# 1/1 [==============================] - 0s 466ms/step
# 5052
# imagesPdf\image0327.png
# 1/1 [==============================] - 1s 526ms/step
# 1048
# imagesPdf\image1328.png
# 1/1 [==============================] - 1s 536ms/step
# 5021
# imagesPdf\image0329.png
# 1/1 [==============================] - 0s 492ms/step
# 2839
# imagesPdf\image1330.png
# 1/1 [==============================] - 1s 533ms/step
# 0
# Contract\image0331.png
# 1/1 [==============================] - 1s 545ms/step
# 4963
# imagesPdf\image0332.png
# 1/1 [==============================] - 1s 624ms/step
# 2798
# imagesPdf\image1333.png
# 1/1 [==============================] - 1s 595ms/step
# 5077
# imagesPdf\image0334.png
# 1/1 [==============================] - 1s 597ms/step
# 0
# Contract\image1335.png
# 1/1 [==============================] - 1s 603ms/step
# 20
# Contract\image2336.png
# 1/1 [==============================] - 0s 477ms/step
# 174
# Contract\image0337.png
# 1/1 [==============================] - 1s 537ms/step
# 4734
# imagesPdf\image1338.png
# 1/1 [==============================] - 1s 604ms/step
# 4779
# imagesPdf\image0339.png
# 1/1 [==============================] - 1s 663ms/step
# 104
# Contract\image1340.png
# 1/1 [==============================] - 1s 606ms/step
# 6168
# imagesPdf\image0341.png
# 1/1 [==============================] - 1s 618ms/step
# 0
# Contract\image1342.png
# 1/1 [==============================] - 1s 612ms/step
# 0
# Contract\image2343.png
# 1/1 [==============================] - 1s 574ms/step
# 4777
# imagesPdf\image0344.png
# 1/1 [==============================] - 1s 625ms/step
# 0
# Contract\image1345.png
# 1/1 [==============================] - 1s 611ms/step
# 4800
# imagesPdf\image2346.png
# 1/1 [==============================] - 1s 630ms/step
# 0
# Contract\image3347.png
# 1/1 [==============================] - 1s 719ms/step
# 4993
# imagesPdf\image0348.png
# 1/1 [==============================] - 1s 632ms/step
# 2984
# imagesPdf\image1349.png
# 1/1 [==============================] - 1s 528ms/step
# 0
# Contract\image2350.png
# 1/1 [==============================] - 1s 616ms/step
# 3056
# imagesPdf\image0351.png
# 1/1 [==============================] - 1s 555ms/step
# 4757
# imagesPdf\image1352.png
# 1/1 [==============================] - 1s 588ms/step
# 0
# Contract\image2353.png
# 1/1 [==============================] - 1s 560ms/step
# 4974
# imagesPdf\image0354.png
# 1/1 [==============================] - 1s 586ms/step
# 1674
# imagesPdf\image1355.png
# 1/1 [==============================] - 1s 582ms/step
# 4
# Contract\image2356.png
# 1/1 [==============================] - 1s 512ms/step
# 4973
# imagesPdf\image0357.png
# 1/1 [==============================] - 1s 594ms/step
# 5526
# imagesPdf\image1358.png
# 1/1 [==============================] - 0s 440ms/step
# 5011
# imagesPdf\image0359.png
# 1/1 [==============================] - 0s 495ms/step
# 154
# Contract\image1360.png
# 1/1 [==============================] - 1s 603ms/step
# 2033
# imagesPdf\image0361.png
# 1/1 [==============================] - 1s 613ms/step
# 4792
# imagesPdf\image1362.png
# 1/1 [==============================] - 1s 569ms/step
# 0
# Contract\image2363.png
# 1/1 [==============================] - 1s 613ms/step
# 5011
# imagesPdf\image0364.png
# 1/1 [==============================] - 1s 616ms/step
# 2686
# imagesPdf\image1365.png
# 1/1 [==============================] - 1s 642ms/step
# 4955
# imagesPdf\image0366.png
# 1/1 [==============================] - 1s 627ms/step
# 2124
# imagesPdf\image1367.png
# 1/1 [==============================] - 1s 616ms/step
# 5040
# imagesPdf\image0368.png
# 1/1 [==============================] - 1s 541ms/step
# 2255
# imagesPdf\image1369.png
# 1/1 [==============================] - 1s 593ms/step
# 118
# Contract\image0370.png
# 1/1 [==============================] - 1s 588ms/step
# 8338
# imagesPdf\image0371.png
# 1/1 [==============================] - 1s 584ms/step
# 0
# Contract\image1372.png
# 1/1 [==============================] - 1s 515ms/step
# 0
# Contract\image2373.png
# 1/1 [==============================] - 1s 578ms/step
# 0
# Contract\image3374.png
# 1/1 [==============================] - 1s 540ms/step
# 5157
# imagesPdf\image0375.png
# 1/1 [==============================] - 1s 540ms/step
# 973
# imagesPdf\image1376.png
# 1/1 [==============================] - 0s 487ms/step
# 0
# Contract\image0377.png
# 1/1 [==============================] - 1s 620ms/step
# 3366
# imagesPdf\image0378.png
# 1/1 [==============================] - 1s 506ms/step
# 2111
# imagesPdf\image1379.png
# 1/1 [==============================] - 1s 584ms/step
# 5000
# imagesPdf\image0380.png
# 1/1 [==============================] - 1s 610ms/step
# 295
# Contract\image1381.png
# 1/1 [==============================] - 1s 634ms/step
# 0
# Contract\image2382.png
# 1/1 [==============================] - 1s 663ms/step
# 0
# Contract\image0383.png
# 1/1 [==============================] - 1s 566ms/step
# 4963
# imagesPdf\image0384.png
# 1/1 [==============================] - 1s 644ms/step
# 2798
# imagesPdf\image1385.png
# 1/1 [==============================] - 1s 649ms/step
# 4990
# imagesPdf\image0386.png
# 1/1 [==============================] - 1s 622ms/step
# 3746
# imagesPdf\image1387.png
# 1/1 [==============================] - 1s 584ms/step
# 5745
# imagesPdf\image0388.png
# 1/1 [==============================] - 1s 591ms/step
# 0
# Contract\image1389.png
# 1/1 [==============================] - 1s 502ms/step
# 5078
# imagesPdf\image0390.png
# 1/1 [==============================] - 1s 592ms/step
# 4832
# imagesPdf\image0391.png
# 1/1 [==============================] - 1s 686ms/step
# 0
# Contract\image1392.png
# 1/1 [==============================] - 1s 595ms/step
# 5024
# imagesPdf\image0393.png
# 1/1 [==============================] - 1s 540ms/step
# 2115
# imagesPdf\image1394.png
# 1/1 [==============================] - 0s 485ms/step
# 4973
# imagesPdf\image0395.png
# 1/1 [==============================] - 1s 512ms/step
# 1556
# imagesPdf\image1396.png
# 1/1 [==============================] - 1s 594ms/step
# 10
# Contract\image2397.png
# 1/1 [==============================] - 1s 529ms/step
# 4806
# imagesPdf\image0398.png
# 1/1 [==============================] - 1s 576ms/step
# 12
# Contract\image1399.png
# 1/1 [==============================] - 1s 607ms/step
# 0
# Contract\image2400.png
# 1/1 [==============================] - 1s 646ms/step
# 6133
# imagesPdf\image0401.png
# 1/1 [==============================] - 1s 558ms/step
# 4803
# imagesPdf\image0402.png
# 1/1 [==============================] - 0s 488ms/step
# 412
# imagesPdf\image1403.png
# 1/1 [==============================] - 1s 589ms/step
# 5091
# imagesPdf\image0404.png
# 1/1 [==============================] - 1s 533ms/step
# 41
# Contract\image1405.png
# 1/1 [==============================] - 0s 496ms/step
# 5031
# imagesPdf\image0406.png
# 1/1 [==============================] - 1s 586ms/step
# 3381
# imagesPdf\image1407.png
# 1/1 [==============================] - 1s 581ms/step
# 6
# Contract\image2408.png
# 1/1 [==============================] - 1s 637ms/step
# 4
# Contract\image0409.png
# 1/1 [==============================] - 1s 520ms/step
# 1
# Contract\image0410.png
# 1/1 [==============================] - 1s 536ms/step
# 4741
# imagesPdf\image0411.png
# 1/1 [==============================] - 1s 612ms/step
# 8
# Contract\image1412.png
# 1/1 [==============================] - 1s 607ms/step
# 4759
# imagesPdf\image0413.png
# 1/1 [==============================] - 1s 565ms/step
# 100
# Contract\image1414.png
# 1/1 [==============================] - 1s 542ms/step
# 4786
# imagesPdf\image2415.png
# 1/1 [==============================] - 1s 552ms/step
# 0
# Contract\image3416.png
# 1/1 [==============================] - 1s 548ms/step
# 856
# imagesPdf\image0417.png
# 1/1 [==============================] - 0s 496ms/step
# 4755
# imagesPdf\image1418.png
# 1/1 [==============================] - 1s 640ms/step
# 0
# Contract\image2419.png
# 1/1 [==============================] - 1s 524ms/step
# 4701
# imagesPdf\image0420.png
# 1/1 [==============================] - 1s 604ms/step
# 0
# Contract\image1421.png
# 1/1 [==============================] - 1s 612ms/step
# 4995
# imagesPdf\image0422.png
# 1/1 [==============================] - 1s 571ms/step
# 2196
# imagesPdf\image1423.png
# 1/1 [==============================] - 1s 531ms/step
# 99
# Contract\image2424.png
# 1/1 [==============================] - 1s 510ms/step
# 5078
# imagesPdf\image0425.png
# 1/1 [==============================] - 1s 637ms/step
# 4758
# imagesPdf\image0426.png
# 1/1 [==============================] - 1s 615ms/step
# 3753
# imagesPdf\image1427.png
# 1/1 [==============================] - 1s 630ms/step
# 5133
# imagesPdf\image0428.png
# 1/1 [==============================] - 1s 597ms/step
# 4761
# imagesPdf\image0429.png
# 1/1 [==============================] - 1s 606ms/step
# 0
# Contract\image1430.png
# 1/1 [==============================] - 1s 547ms/step
# 4784
# imagesPdf\image0431.png
# 1/1 [==============================] - 1s 613ms/step
# 1379
# imagesPdf\image1432.png
# 1/1 [==============================] - 1s 601ms/step
# 4993
# imagesPdf\image0433.png
# 1/1 [==============================] - 1s 598ms/step
# 2325
# imagesPdf\image1434.png
# 1/1 [==============================] - 1s 598ms/step
# 4967
# imagesPdf\image0435.png
# 1/1 [==============================] - 1s 601ms/step
# 1803
# imagesPdf\image1436.png
# 1/1 [==============================] - 0s 497ms/step
# 1167
# imagesPdf\image2437.png
# 1/1 [==============================] - 1s 546ms/step
# 4987
# imagesPdf\image0438.png
# 1/1 [==============================] - 1s 602ms/step
# 816
# imagesPdf\image1439.png
# 1/1 [==============================] - 1s 617ms/step
# 1851
# imagesPdf\image0440.png
# 1/1 [==============================] - 1s 593ms/step
# 5049
# imagesPdf\image1441.png
# 1/1 [==============================] - 1s 584ms/step
# 0
# Contract\image0442.png
# 1/1 [==============================] - 1s 553ms/step
# 4794
# imagesPdf\image1443.png
# 1/1 [==============================] - 1s 506ms/step
# 4786
# imagesPdf\image0444.png
# 1/1 [==============================] - 1s 565ms/step
# 0
# Contract\image1445.png
# 1/1 [==============================] - 1s 650ms/step
# 0
# Contract\image2446.png
# 1/1 [==============================] - 1s 556ms/step
# 4973
# imagesPdf\image0447.png
# 1/1 [==============================] - 1s 598ms/step
# 5526
# imagesPdf\image1448.png
# 1/1 [==============================] - 1s 604ms/step
# 16
# Contract\image0449.png
# 1/1 [==============================] - 1s 594ms/step
# 119
# Contract\image1450.png
# 1/1 [==============================] - 1s 572ms/step
# 4748
# imagesPdf\image2451.png
# 1/1 [==============================] - 1s 545ms/step
# 7
# Contract\image3452.png
# 1/1 [==============================] - 1s 567ms/step
# 5980
# imagesPdf\image0453.png
# 1/1 [==============================] - 1s 617ms/step
# 5040
# imagesPdf\image0454.png
# 1/1 [==============================] - 1s 624ms/step
# 2255
# imagesPdf\image1455.png
# 1/1 [==============================] - 1s 601ms/step
# 4900
# imagesPdf\image0456.png
# 1/1 [==============================] - 1s 632ms/step
# 3136
# imagesPdf\image1457.png
# 1/1 [==============================] - 1s 595ms/step
# 5179
# imagesPdf\image0458.png
# 1/1 [==============================] - 1s 609ms/step
# 0
# Contract\image1459.png
# 1/1 [==============================] - 1s 519ms/step
# 0
# Contract\image2460.png
# 1/1 [==============================] - 1s 632ms/step
# 5052
# imagesPdf\image0461.png
# 1/1 [==============================] - 1s 547ms/step
# 1048
# imagesPdf\image1462.png
# 1/1 [==============================] - 1s 599ms/step
# 4990
# imagesPdf\image0463.png
# 1/1 [==============================] - 1s 622ms/step
# 0
# Contract\image1464.png
# 1/1 [==============================] - 1s 600ms/step
# 7254
# imagesPdf\image0465.png
# 1/1 [==============================] - 1s 617ms/step
# 0
# Contract\image1466.png
# 1/1 [==============================] - 1s 639ms/step
# 0
# Contract\image2467.png
# 1/1 [==============================] - 1s 521ms/step
# 4990
# imagesPdf\image0468.png
# 1/1 [==============================] - 1s 610ms/step
# 3746
# imagesPdf\image1469.png
# 1/1 [==============================] - 1s 554ms/step
# 4982
# imagesPdf\image0470.png
# 1/1 [==============================] - 1s 618ms/step
# 2412
# imagesPdf\image1471.png
# 1/1 [==============================] - 1s 590ms/step
# 6
# Contract\image2472.png
# 1/1 [==============================] - 1s 593ms/step
# 1623
# imagesPdf\image0473.png
# 1/1 [==============================] - 1s 570ms/step
# 5031
# imagesPdf\image1474.png
# 1/1 [==============================] - 1s 608ms/step
# 232
# Contract\image2475.png
# 1/1 [==============================] - 1s 635ms/step
# 4758
# imagesPdf\image0476.png
# 1/1 [==============================] - 1s 514ms/step
# 3753
# imagesPdf\image1477.png
# 1/1 [==============================] - 1s 509ms/step
# 4998
# imagesPdf\image0478.png
# 1/1 [==============================] - 1s 541ms/step
# 447
# imagesPdf\image1479.png
# 1/1 [==============================] - 1s 616ms/step
# 0
# Contract\image0480.png
# 1/1 [==============================] - 1s 630ms/step
# 4761
# imagesPdf\image0481.png
# 1/1 [==============================] - 1s 642ms/step
# 0
# Contract\image1482.png
# 1/1 [==============================] - 1s 604ms/step
# 0
# Contract\image0483.png
# 1/1 [==============================] - 1s 595ms/step
# 6322
# imagesPdf\image0484.png
# 1/1 [==============================] - 1s 601ms/step
# 0
# Contract\image0485.png
# 1/1 [==============================] - 1s 607ms/step
# 6133
# imagesPdf\image0486.png
# 1/1 [==============================] - 1s 607ms/step
# 4926
# imagesPdf\image0487.png
# 1/1 [==============================] - 1s 612ms/step
# 0
# Contract\image1488.png
# 1/1 [==============================] - 1s 586ms/step
# 0
# Contract\image2489.png
# 1/1 [==============================] - 1s 579ms/step
# 4802
# imagesPdf\image0490.png
# 1/1 [==============================] - 1s 544ms/step
# 205
# Contract\image1491.png
# 1/1 [==============================] - 1s 652ms/step
# 0
# Contract\image0492.png
# 1/1 [==============================] - 1s 606ms/step
# 4794
# imagesPdf\image1493.png
# 1/1 [==============================] - 1s 546ms/step
# 0
# Contract\image0494.png
# 1/1 [==============================] - 1s 565ms/step
# 5076
# imagesPdf\image0495.png
# 1/1 [==============================] - 1s 564ms/step
# 2
# Contract\image1496.png
# 1/1 [==============================] - 1s 614ms/step
# 4782
# imagesPdf\image0497.png
# 1/1 [==============================] - 1s 636ms/step
# 0
# Contract\image1498.png
# 1/1 [==============================] - 1s 601ms/step
# 5040
# imagesPdf\image0499.png
# 1/1 [==============================] - 1s 541ms/step
# 3389
# imagesPdf\image1500.png
# 1/1 [==============================] - 1s 639ms/step
# 5012
# imagesPdf\image0501.png
# 1/1 [==============================] - 1s 615ms/step
# 391
# imagesPdf\image1502.png
# 1/1 [==============================] - 1s 590ms/step
# 1
# Contract\image2503.png
# 1/1 [==============================] - 1s 544ms/step
# 8338
# imagesPdf\image0504.png
# 1/1 [==============================] - 1s 566ms/step
# 0
# Contract\image1505.png
# 1/1 [==============================] - 0s 489ms/step
# 0
# Contract\image2506.png
# 1/1 [==============================] - 1s 589ms/step
# 0
# Contract\image3507.png
# 1/1 [==============================] - 1s 608ms/step
# 4963
# imagesPdf\image0508.png
# 1/1 [==============================] - 1s 616ms/step
# 2798
# imagesPdf\image1509.png
# 1/1 [==============================] - 1s 698ms/step
# 4994
# imagesPdf\image0510.png
# 1/1 [==============================] - 1s 652ms/step
# 2348
# imagesPdf\image1511.png
# 1/1 [==============================] - 1s 620ms/step
# 4749
# imagesPdf\image0512.png
# 1/1 [==============================] - 1s 600ms/step
# 0
# Contract\image1513.png
# 1/1 [==============================] - 1s 562ms/step
# 4790
# imagesPdf\image2514.png
# 1/1 [==============================] - 1s 569ms/step
# 5072
# imagesPdf\image0515.png
# 1/1 [==============================] - 1s 607ms/step
# 2297
# imagesPdf\image1516.png
# 1/1 [==============================] - 1s 578ms/step
# 0
# Contract\image2517.png
# 1/1 [==============================] - 1s 571ms/step
# 4758
# imagesPdf\image0518.png
# 1/1 [==============================] - 1s 585ms/step
# 3753
# imagesPdf\image1519.png
# 1/1 [==============================] - 1s 574ms/step
# 4747
# imagesPdf\image0520.png
# 1/1 [==============================] - 0s 422ms/step
# 114
# Contract\image1521.png
# 1/1 [==============================] - 1s 581ms/step
# 5029
# imagesPdf\image0522.png
# 1/1 [==============================] - 1s 565ms/step
# 288
# Contract\image0523.png
# 1/1 [==============================] - 1s 512ms/step
# 4804
# imagesPdf\image0524.png
# 1/1 [==============================] - 1s 630ms/step
# 0
# Contract\image1525.png
# 1/1 [==============================] - 1s 522ms/step
# 5056
# imagesPdf\image0526.png
# 1/1 [==============================] - 0s 479ms/step
# 1941
# imagesPdf\image1527.png
# 1/1 [==============================] - 1s 601ms/step
# 0
# Contract\image2528.png
# 1/1 [==============================] - 1s 603ms/step
# 4657
# imagesPdf\image0529.png
# 1/1 [==============================] - 1s 572ms/step
# 0
# Contract\image1530.png
# 1/1 [==============================] - 1s 506ms/step
# 0
# Contract\image2531.png
# 1/1 [==============================] - 1s 524ms/step
# 7
# Contract\image0532.png
# 1/1 [==============================] - 1s 513ms/step
# 4973
# imagesPdf\image0533.png
# 1/1 [==============================] - 1s 620ms/step
# 1060
# imagesPdf\image1534.png
# 1/1 [==============================] - 1s 529ms/step
# 515
# imagesPdf\image2535.png
# 1/1 [==============================] - 0s 490ms/step
# 0
# Contract\image0536.png
# 1/1 [==============================] - 1s 521ms/step
# 4952
# imagesPdf\image0537.png
# 1/1 [==============================] - 1s 508ms/step
# 2287
# imagesPdf\image1538.png
# 1/1 [==============================] - 1s 569ms/step
# 25
# Contract\image2539.png
# 1/1 [==============================] - 1s 593ms/step
# 5007
# imagesPdf\image0540.png
# 1/1 [==============================] - 1s 547ms/step
# 80
# Contract\image1541.png
# 1/1 [==============================] - 1s 542ms/step
# 36
# Contract\image2542.png
# 1/1 [==============================] - 0s 497ms/step
# 4696
# imagesPdf\image0543.png
# 1/1 [==============================] - 1s 603ms/step
# 664
# imagesPdf\image1544.png
# 1/1 [==============================] - 1s 626ms/step
# 0
# Contract\image0545.png
# 1/1 [==============================] - 1s 528ms/step
# 0
# Contract\image0546.png
# 1/1 [==============================] - 0s 483ms/step
# 21
# Contract\image1547.png
# 1/1 [==============================] - 1s 574ms/step
# 6
# Contract\image2548.png
# 1/1 [==============================] - 1s 562ms/step
# 9
# Contract\image3549.png
# 1/1 [==============================] - 1s 532ms/step
# 3
# Contract\image4550.png
# 1/1 [==============================] - 1s 592ms/step
# 6
# Contract\image5551.png
# 1/1 [==============================] - 1s 560ms/step
# 0
# Contract\image6552.png
# 1/1 [==============================] - 0s 488ms/step
# 0
# Contract\image7553.png
# 1/1 [==============================] - 1s 596ms/step
# 0
# Contract\image8554.png
# 1/1 [==============================] - 1s 541ms/step
# 0
# Contract\image9555.png
# 1/1 [==============================] - 1s 607ms/step
# 5980
# imagesPdf\image0556.png
# 1/1 [==============================] - 0s 498ms/step
# 5350
# imagesPdf\image0557.png
# 1/1 [==============================] - 0s 497ms/step
# 2889
# imagesPdf\image1558.png
# 1/1 [==============================] - 1s 585ms/step
# 5027
# imagesPdf\image0559.png
# 1/1 [==============================] - 1s 630ms/step
# 1372
# imagesPdf\image1560.png
# 1/1 [==============================] - 1s 592ms/step
# 4751
# imagesPdf\image0561.png
# 1/1 [==============================] - 1s 561ms/step
# 1698
# imagesPdf\image1562.png
# 1/1 [==============================] - 1s 580ms/step
# 6585
# imagesPdf\image0563.png
# 1/1 [==============================] - 1s 518ms/step
# 5076
# imagesPdf\image0564.png
# 1/1 [==============================] - 1s 687ms/step
# 2
# Contract\image1565.png
# 1/1 [==============================] - 1s 553ms/step
# 5756
# imagesPdf\image0566.png
# 1/1 [==============================] - 1s 561ms/step
# 4998
# imagesPdf\image0567.png
# 1/1 [==============================] - 1s 602ms/step
# 447
# imagesPdf\image1568.png
# 1/1 [==============================] - 1s 502ms/step
# 0
# Contract\image0569.png
# 1/1 [==============================] - 1s 615ms/step
# 5756
# imagesPdf\image0570.png
# 1/1 [==============================] - 1s 615ms/step
# 4998
# imagesPdf\image0571.png
# 1/1 [==============================] - 1s 583ms/step
# 3389
# imagesPdf\image1572.png
# 1/1 [==============================] - 1s 584ms/step
# 0
# Contract\image0573.png
# 1/1 [==============================] - 1s 502ms/step
# 5091
# imagesPdf\image0574.png
# 1/1 [==============================] - 1s 502ms/step
# 41
# Contract\image1575.png
# 1/1 [==============================] - 1s 521ms/step
# 5
# Contract\image0576.png
# 1/1 [==============================] - 1s 571ms/step
# 0
# Contract\image1577.png
# 1/1 [==============================] - 0s 498ms/step
# 0
# Contract\image2578.png
# 1/1 [==============================] - 0s 482ms/step
# 0
# Contract\image3579.png
# 1/1 [==============================] - 1s 532ms/step
# 0
# Contract\image4580.png
# 1/1 [==============================] - 1s 594ms/step
# 0
# Contract\image5581.png
# 1/1 [==============================] - 1s 524ms/step
# 0
# Contract\image6582.png
# 1/1 [==============================] - 0s 498ms/step
# 0
# Contract\image7583.png
# 1/1 [==============================] - 0s 449ms/step
# 0
# Contract\image8584.png
# 1/1 [==============================] - 0s 450ms/step
# 0
# Contract\image9585.png
# 1/1 [==============================] - 1s 565ms/step
# 5210
# imagesPdf\image0586.png
# 1/1 [==============================] - 1s 560ms/step
# 3101
# imagesPdf\image1587.png
# 1/1 [==============================] - 1s 573ms/step
# 0
# Contract\image0588.png
# 1/1 [==============================] - 1s 512ms/step
# 4998
# imagesPdf\image0589.png
# 1/1 [==============================] - 1s 531ms/step
# 3389
# imagesPdf\image1590.png
# 1/1 [==============================] - 1s 590ms/step
# 0
# Contract\image0591.png
# 1/1 [==============================] - 1s 513ms/step
# 21
# Contract\image1592.png
# 1/1 [==============================] - 0s 496ms/step
# 6
# Contract\image2593.png
# 1/1 [==============================] - 0s 486ms/step
# 9
# Contract\image3594.png
# 1/1 [==============================] - 1s 588ms/step
# 3
# Contract\image4595.png
# 1/1 [==============================] - 1s 539ms/step
# 6
# Contract\image5596.png
# ...
# 3
# Contract\image12305.png
# 1/1 [==============================] - 1s 630ms/step
# 5980
# imagesPdf\image02306.png
# 1/1 [==============================] - 1s 648ms/step
# 2164
# imagesPdf\image02307.png
# 1/1 [==============================] - 1s 680ms/step
# 4975
# imagesPdf\image12308.png
# 1/1 [==============================] - 0s 459ms/step
# 5018
# imagesPdf\image02309.png
# 1/1 [==============================] - 1s 583ms/step
# 0
# Contract\image12310.png
# 1/1 [==============================] - 1s 543ms/step
# 5133
# imagesPdf\image02311.png
# 1/1 [==============================] - 1s 565ms/step
# 5027
# imagesPdf\image02312.png
# 1/1 [==============================] - 1s 537ms/step
# 1372
# imagesPdf\image12313.png
# 1/1 [==============================] - 1s 550ms/step
# 4974
# imagesPdf\image02314.png
# 1/1 [==============================] - 0s 478ms/step
# 1674
# imagesPdf\image12315.png
# 1/1 [==============================] - 1s 685ms/step
# 0
# Contract\image22316.png
# 1/1 [==============================] - 1s 646ms/step
# 0
# Contract\image02317.png
# 1/1 [==============================] - 1s 703ms/step
# 0
# Contract\image02318.png
# 1/1 [==============================] - 1s 678ms/step
# 6472
# imagesPdf\image02319.png
# 1/1 [==============================] - 1s 512ms/step
# 4797
# imagesPdf\image02320.png
# 1/1 [==============================] - 1s 592ms/step
# 0
# Contract\image12321.png
# 1/1 [==============================] - 1s 519ms/step
# 4
# Contract\image02322.png
# 1/1 [==============================] - 1s 620ms/step
# 148
# Contract\image02323.png
# 1/1 [==============================] - 1s 658ms/step
# 0
# Contract\image02324.png
# 1/1 [==============================] - 0s 463ms/step
# 4990
# imagesPdf\image02325.png
# 1/1 [==============================] - 1s 554ms/step
# 3746
# imagesPdf\image12326.png
# 1/1 [==============================] - 0s 479ms/step
# 4811
# imagesPdf\image02327.png
# 1/1 [==============================] - 1s 543ms/step
# 0
# Contract\image12328.png
# 1/1 [==============================] - 0s 481ms/step
# 5055
# imagesPdf\image02329.png
# 1/1 [==============================] - 1s 522ms/step
# 3375
# imagesPdf\image12330.png
# 1/1 [==============================] - 0s 481ms/step
# 5462
# imagesPdf\image02331.png
# 1/1 [==============================] - 1s 553ms/step
# 2387
# imagesPdf\image12332.png
# 1/1 [==============================] - 0s 472ms/step
# 4987
# imagesPdf\image02333.png
# 1/1 [==============================] - 0s 465ms/step
# 4372
# imagesPdf\image12334.png
# 1/1 [==============================] - 1s 560ms/step
# 10
# Contract\image02335.png
# 1/1 [==============================] - 1s 504ms/step
# 4788
# imagesPdf\image12336.png
# 1/1 [==============================] - 0s 479ms/step
# 1
# Contract\image22337.png
# 1/1 [==============================] - 0s 428ms/step
# 4979
# imagesPdf\image02338.png
# 1/1 [==============================] - 0s 440ms/step
# 2152
# imagesPdf\image12339.png
# 1/1 [==============================] - 1s 544ms/step
# 7
# Contract\image22340.png
# 1/1 [==============================] - 1s 553ms/step
# 5018
# imagesPdf\image02341.png
# 1/1 [==============================] - 1s 518ms/step
# 2981
# imagesPdf\image12342.png
# 1/1 [==============================] - 1s 552ms/step
# 0
# Contract\image22343.png
# 1/1 [==============================] - 1s 634ms/step
# 0
# Contract\image02344.png
# 1/1 [==============================] - 1s 558ms/step
# 4960
# imagesPdf\image02345.png
# 1/1 [==============================] - 1s 708ms/step
# 3266
# imagesPdf\image12346.png
# 1/1 [==============================] - 1s 727ms/step
# 0
# Contract\image22347.png
# 1/1 [==============================] - 1s 724ms/step
# 4978
# imagesPdf\image02348.png
# 1/1 [==============================] - 1s 895ms/step
# 3346
# imagesPdf\image12349.png
# 1/1 [==============================] - 1s 675ms/step
# 4978
# imagesPdf\image02350.png
# 1/1 [==============================] - 1s 935ms/step
# 3346
# imagesPdf\image12351.png
# 1/1 [==============================] - 1s 942ms/step
# 144
# Contract\image02352.png
# 1/1 [==============================] - 1s 729ms/step
# 5116
# imagesPdf\image12353.png
# 1/1 [==============================] - 1s 797ms/step
# 0
# Contract\image22354.png
# 1/1 [==============================] - 1s 731ms/step
# 5051
# imagesPdf\image02355.png
# 1/1 [==============================] - 1s 1s/step
# 1793
# imagesPdf\image12356.png
# 1/1 [==============================] - 1s 921ms/step
# 28
# Contract\image22357.png
# 1/1 [==============================] - 1s 1s/step
# 4976
# imagesPdf\image02358.png
# 1/1 [==============================] - 1s 831ms/step
# 2901
# imagesPdf\image12359.png
# 1/1 [==============================] - 1s 734ms/step
# 4780
# imagesPdf\image02360.png
# 1/1 [==============================] - 1s 797ms/step
# 5201
# imagesPdf\image02361.png
# 1/1 [==============================] - 1s 906ms/step
# 2923
# imagesPdf\image12362.png
# 1/1 [==============================] - 1s 795ms/step
# 4937
# imagesPdf\image02363.png
# 1/1 [==============================] - 1s 818ms/step
# 4584
# imagesPdf\image12364.png
# 1/1 [==============================] - 1s 729ms/step
# 5003
# imagesPdf\image02365.png
# 1/1 [==============================] - 1s 869ms/step
# 3
# Contract\image12366.png
# 1/1 [==============================] - 1s 629ms/step
# 4782
# imagesPdf\image02367.png
# 1/1 [==============================] - 1s 670ms/step
# 106
# Contract\image12368.png
# 1/1 [==============================] - 1s 1s/step
# 4761
# imagesPdf\image02369.png
# 1/1 [==============================] - 1s 717ms/step
# 0
# Contract\image12370.png
# 1/1 [==============================] - 1s 565ms/step
# 4801
# imagesPdf\image02371.png
# 1/1 [==============================] - 1s 589ms/step
# 1168
# imagesPdf\image12372.png
# 1/1 [==============================] - 1s 576ms/step
# 4973
# imagesPdf\image02373.png
# 1/1 [==============================] - 0s 487ms/step
# 1556
# imagesPdf\image12374.png
# 1/1 [==============================] - 1s 549ms/step
# 39
# Contract\image22375.png
# 1/1 [==============================] - 1s 535ms/step
# 4989
# imagesPdf\image02376.png
# 1/1 [==============================] - 1s 575ms/step
# 1311
# imagesPdf\image12377.png
# 1/1 [==============================] - 1s 591ms/step
# 1
# Contract\image22378.png
# 1/1 [==============================] - 0s 459ms/step
# 4977
# imagesPdf\image02379.png
# 1/1 [==============================] - 1s 704ms/step
# 3493
# imagesPdf\image12380.png
# 1/1 [==============================] - 0s 495ms/step
# 2
# Contract\image22381.png
# 1/1 [==============================] - 0s 491ms/step
# 0
# Contract\image02382.png
# 1/1 [==============================] - 1s 519ms/step
# 5201
# imagesPdf\image02383.png
# 1/1 [==============================] - 1s 534ms/step
# 2923
# imagesPdf\image12384.png
# 1/1 [==============================] - 0s 426ms/step
# 5003
# imagesPdf\image02385.png
# 1/1 [==============================] - 1s 563ms/step
# 3219
# imagesPdf\image12386.png
# 1/1 [==============================] - 0s 434ms/step
# 5025
# imagesPdf\image02387.png
# 1/1 [==============================] - 0s 447ms/step
# 3679
# imagesPdf\image12388.png
# 1/1 [==============================] - 1s 531ms/step
# 3366
# imagesPdf\image02389.png
# 1/1 [==============================] - 1s 542ms/step
# 2111
# imagesPdf\image12390.png
# 1/1 [==============================] - 0s 456ms/step
# 4701
# imagesPdf\image02391.png
# 1/1 [==============================] - 1s 522ms/step
# 0
# Contract\image12392.png
# 1/1 [==============================] - 1s 504ms/step
# 0
# Contract\image02393.png
# 1/1 [==============================] - 1s 547ms/step
# 4790
# imagesPdf\image12394.png
# 1/1 [==============================] - 1s 558ms/step
# 0
# Contract\image22395.png
# 1/1 [==============================] - 1s 505ms/step
# 0
# Contract\image32396.png
# 1/1 [==============================] - 1s 610ms/step
# 4804
# imagesPdf\image02397.png
# 1/1 [==============================] - 0s 480ms/step
# 1828
# imagesPdf\image12398.png
# 1/1 [==============================] - 1s 531ms/step
# 4792
# imagesPdf\image02399.png
# 1/1 [==============================] - 0s 494ms/step
# 0
# Contract\image12400.png
# 1/1 [==============================] - 1s 539ms/step
# 5087
# imagesPdf\image02401.png
# 1/1 [==============================] - 0s 481ms/step
# 3174
# imagesPdf\image12402.png
# 1/1 [==============================] - 1s 530ms/step
# 4
# Contract\image22403.png
# 1/1 [==============================] - 1s 572ms/step
# 5033
# imagesPdf\image02404.png
# 1/1 [==============================] - 1s 560ms/step
# 356
# imagesPdf\image12405.png
# 1/1 [==============================] - 0s 431ms/step
# 5010
# imagesPdf\image02406.png
# 1/1 [==============================] - 1s 515ms/step
# 1991
# imagesPdf\image12407.png
# 1/1 [==============================] - 0s 455ms/step
# 5104
# imagesPdf\image02408.png
# 1/1 [==============================] - 0s 479ms/step
# 4181
# imagesPdf\image12409.png
# 1/1 [==============================] - 0s 449ms/step
# 0
# Contract\image02410.png
# 1/1 [==============================] - 1s 615ms/step
# 0
# Contract\image12411.png
# 1/1 [==============================] - 1s 500ms/step
# 3366
# imagesPdf\image02412.png
# 1/1 [==============================] - 1s 534ms/step
# 2111
# imagesPdf\image12413.png
# 1/1 [==============================] - 1s 505ms/step
# 4779
# imagesPdf\image02414.png
# 1/1 [==============================] - 1s 550ms/step
# 104
# Contract\image12415.png
# 1/1 [==============================] - 0s 474ms/step
# 5189
# imagesPdf\image02416.png
# 1/1 [==============================] - 0s 445ms/step
# 0
# Contract\image12417.png
# 1/1 [==============================] - 1s 533ms/step
# 4786
# imagesPdf\image02418.png
# 1/1 [==============================] - 0s 454ms/step
# 0
# Contract\image12419.png
# 1/1 [==============================] - 0s 475ms/step
# 4797
# imagesPdf\image02420.png
# 1/1 [==============================] - 0s 473ms/step
# 0
# Contract\image12421.png
# 1/1 [==============================] - 0s 477ms/step
# 4961
# imagesPdf\image02422.png
# 1/1 [==============================] - 1s 541ms/step
# 2470
# imagesPdf\image12423.png
# 1/1 [==============================] - 0s 488ms/step
# 0
# Contract\image22424.png
# 1/1 [==============================] - 1s 532ms/step
# 1661
# imagesPdf\image02425.png
# 1/1 [==============================] - 0s 469ms/step
# 4891
# imagesPdf\image12426.png
# 1/1 [==============================] - 1s 552ms/step
# 4980
# imagesPdf\image02427.png
# 1/1 [==============================] - 1s 539ms/step
# 203
# Contract\image12428.png
# 1/1 [==============================] - 0s 495ms/step
# 5021
# imagesPdf\image02429.png
# 1/1 [==============================] - 1s 562ms/step
# 811
# imagesPdf\image12430.png
# 1/1 [==============================] - 1s 590ms/step
# 4966
# imagesPdf\image02431.png
# 1/1 [==============================] - 0s 484ms/step
# 2934
# imagesPdf\image12432.png
# 1/1 [==============================] - 1s 540ms/step
# 5004
# imagesPdf\image02433.png
# 1/1 [==============================] - 0s 465ms/step
# 1995
# imagesPdf\image12434.png
# 1/1 [==============================] - 0s 483ms/step
# 0
# Contract\image22435.png
# 1/1 [==============================] - 1s 544ms/step
# 4911
# imagesPdf\image02436.png
# 1/1 [==============================] - 0s 490ms/step
# 2964
# imagesPdf\image12437.png
# 1/1 [==============================] - 0s 486ms/step
# 0
# Contract\image02438.png
# 1/1 [==============================] - 1s 639ms/step
# 4754
# imagesPdf\image12439.png
# 1/1 [==============================] - 1s 539ms/step
# 6862
# imagesPdf\image02440.png
# 1/1 [==============================] - 0s 481ms/step
# 75
# Contract\image12441.png
# 1/1 [==============================] - 1s 545ms/step
# 5234
# imagesPdf\image02442.png
# 1/1 [==============================] - 0s 489ms/step
# 0
# Contract\image12443.png
# 1/1 [==============================] - 0s 489ms/step
# 5040
# imagesPdf\image02444.png
# 1/1 [==============================] - 0s 460ms/step
# 2255
# imagesPdf\image12445.png
# 1/1 [==============================] - 0s 464ms/step
# 4995
# imagesPdf\image02446.png
# 1/1 [==============================] - 1s 518ms/step
# 3196
# imagesPdf\image12447.png
# 1/1 [==============================] - 1s 547ms/step
# 5078
# imagesPdf\image02448.png
# 1/1 [==============================] - 0s 475ms/step
# 4811
# imagesPdf\image02449.png
# 1/1 [==============================] - 0s 479ms/step
# 0
# Contract\image12450.png
# 1/1 [==============================] - 0s 447ms/step
# 3366
# imagesPdf\image02451.png
# 1/1 [==============================] - 0s 463ms/step
# 2111
# imagesPdf\image12452.png
# 1/1 [==============================] - 0s 500ms/step
# 4960
# imagesPdf\image02453.png
# 1/1 [==============================] - 1s 524ms/step
# 1197
# imagesPdf\image12454.png
# 1/1 [==============================] - 0s 484ms/step
# 0
# Contract\image22455.png
# 1/1 [==============================] - 1s 525ms/step
# 4911
# imagesPdf\image02456.png
# 1/1 [==============================] - 1s 520ms/step
# 2964
# imagesPdf\image12457.png
# 1/1 [==============================] - 0s 488ms/step
# 4925
# imagesPdf\image02458.png
# 1/1 [==============================] - 1s 519ms/step
# 2794
# imagesPdf\image12459.png
# 1/1 [==============================] - 1s 553ms/step
# 5034
# imagesPdf\image02460.png
# 1/1 [==============================] - 1s 635ms/step
# 3410
# imagesPdf\image12461.png
# 1/1 [==============================] - 0s 494ms/step
# 0
# Contract\image02462.png
# 1/1 [==============================] - 1s 546ms/step
# 4779
# imagesPdf\image02463.png
# 1/1 [==============================] - 1s 635ms/step
# 73
# Contract\image12464.png
# 1/1 [==============================] - 1s 593ms/step
# 4773
# imagesPdf\image02465.png
# 1/1 [==============================] - 1s 512ms/step
# 0
# Contract\image12466.png
# 1/1 [==============================] - 1s 620ms/step
# 2482
# imagesPdf\image02467.png
# 1/1 [==============================] - 1s 542ms/step
# 4737
# imagesPdf\image12468.png
# 1/1 [==============================] - 1s 566ms/step
# 2
# Contract\image22469.png
# 1/1 [==============================] - 1s 577ms/step
# 5251
# imagesPdf\image02470.png
# 1/1 [==============================] - 1s 513ms/step
# 5101
# imagesPdf\image12471.png
# 1/1 [==============================] - 1s 520ms/step
# 1124
# imagesPdf\image22472.png
# 1/1 [==============================] - 1s 580ms/step
# 6322
# imagesPdf\image02473.png
# 1/1 [==============================] - 1s 538ms/step
# 5145
# imagesPdf\image02474.png
# 1/1 [==============================] - 1s 560ms/step
# 0
# Contract\image12475.png
# 1/1 [==============================] - 0s 466ms/step
# 278
# Contract\image02476.png
# 1/1 [==============================] - 1s 539ms/step
# 5084
# imagesPdf\image02477.png
# 1/1 [==============================] - 0s 455ms/step
# 827
# imagesPdf\image12478.png
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pdf2image\pdf2image.py in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     588         if "Pages" not in d:
# --> 589             raise ValueError
#     590
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12096\461670910.py in <module>
#       5 for pdf in list_of_pdfs:
#       6     path_of_pdf = os.path.join(dir_path , pdf)
# ----> 7     images = convert_from_path(path_of_pdf, 500 ,poppler_path = r".\poppler-0.68.0\bin")
#       8     for i, image in enumerate(images):
#       9         Imagesize = image.size
#
# ~\Anaconda3\lib\site-packages\pdf2image\pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, ownerpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#     125         poppler_path = poppler_path.as_posix()
#     126
# --> 127     page_count = pdfinfo_from_path(
#     128         pdf_path, userpw, ownerpw, poppler_path=poppler_path
#     129     )["Pages"]
#
# ~\Anaconda3\lib\site-packages\pdf2image\pdf2image.py in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     596         )
#     597     except ValueError:
# --> 598         raise PDFPageCountError(
#     599             f"Unable to get page count.\n{err.decode('utf8', 'ignore')}"
#     600         )
#
# PDFPageCountError: Unable to get page count.
# Syntax Error: Document stream is empty

# %%
index
# Out:
# 2479

# %%
print(len(os.listdir(".\imagesPdf")))
# Out:
# 1750

# %%
print(len(os.listdir(".\Contract")))
# Out:
# 729
